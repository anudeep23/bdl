# %%
#!git clone https://github.com/anudeep23/CS7643-Final-Project-VOGN

# %%
#%cd /content/CS7643-Final-Project-VOGN

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## datasets.py

# %%
import numpy as np
import torch
import numpy as np
import torchvision.datasets as dset
import torchvision.transforms as transforms
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import TensorDataset
DEFAULT_DATA_FOLDER = './data'

class Dataset():
    def __init__(self, data_set, data_folder = DEFAULT_DATA_FOLDER):
        super(type(self), self).__init__()

        if data_set == 'binary':
            X1 = torch.randn(1000, 50)
            X2 = torch.randn(1000, 50) + 1.5
            X = torch.cat([X1, X2], dim=0)
            Y1 = torch.zeros(1000, 1)
            Y2 = torch.ones(1000, 1)
            Y = torch.cat([Y1, Y2], dim=0)
            self.train_set = TensorDataset(X, Y)
            self.test_set = TensorDataset(X, Y)

        if data_set == 'mnist':
            #self.composed_transforms = transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor()])
            self.train_set = dset.MNIST(root=data_folder,
                                        train=True,
                                        transform=transforms.ToTensor(),
                                        download=True)

            self.test_set = dset.MNIST(root=data_folder,
                                       train=False,
                                       transform=transforms.ToTensor())

        if data_set == 'cifar10':

            #print(type(self.composed_transforms))
            train_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
            test_transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])
            self.train_set = dset.CIFAR10(root=data_folder,
                                          train=True,
                                          transform= train_transform,
                                          download=True)

            self.test_set = dset.CIFAR10(root=data_folder,
                                         train=False,
                                         transform= test_transform)


    def get_train_size(self):
        return len(self.train_set)

    def get_test_size(self):
        return len(self.test_set)

    def get_train_loader(self, batch_size, shuffle=True):
        train_loader = DataLoader(dataset= self.train_set, batch_size=batch_size, shuffle=shuffle, num_workers=8)
        return train_loader

    def get_test_loader(self, batch_size, shuffle=False):
        test_loader = DataLoader(dataset= self.test_set, batch_size=batch_size, shuffle=shuffle, num_workers=8)
        return test_loader

    def load_full_train_set(self, use_cuda=torch.cuda.is_available()):

        full_train_loader = DataLoader(dataset = self.train_set,
                                       batch_size = len(self.train_set),
                                       shuffle = False)

        x_train, y_train = next(iter(full_train_loader))

        if use_cuda:
            x_train, y_train = x_train.cuda(), y_train.cuda()

        return x_train, y_train

    def load_full_test_set(self, use_cuda=torch.cuda.is_available()):

        full_test_loader = DataLoader(dataset = self.test_set,
                                      batch_size = len(self.test_set),
                                      shuffle = False)

        x_test, y_test = next(iter(full_test_loader))

        if use_cuda:
            x_test, y_test = x_test.cuda(), y_test.cuda()

        return x_test, y_test

# %% [markdown]
# ## models.py

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

##################################
## Simple Convolutional Network ##
##################################
class BayesianLinear(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        # Weight parameters
        self.weight_mu = nn.Parameter(torch.Tensor(out_features, in_features).uniform_(-0.2, 0.2))
        self.weight_rho = nn.Parameter(torch.Tensor(out_features, in_features).uniform_(-5,-4))
        self.weight = Gaussian(self.weight_mu, self.weight_rho)
        # Bias parameters
        self.bias_mu = nn.Parameter(torch.Tensor(out_features).uniform_(-0.2, 0.2))
        self.bias_rho = nn.Parameter(torch.Tensor(out_features).uniform_(-5,-4))
        self.bias = Gaussian(self.bias_mu, self.bias_rho)
        # Prior distributions
        self.weight_prior = ScaleMixtureGaussian(PI, SIGMA_1, SIGMA_2)
        self.bias_prior = ScaleMixtureGaussian(PI, SIGMA_1, SIGMA_2)
        self.log_prior = 0
        self.log_variational_posterior = 0

    def forward(self, input, sample=False, calculate_log_probs=False):
        if self.training or sample:
            weight = self.weight.sample()
            bias = self.bias.sample()
        else:
            weight = self.weight.mu
            bias = self.bias.mu
        if self.training or calculate_log_probs:
            self.log_prior = self.weight_prior.log_prob(weight) + self.bias_prior.log_prob(bias)
            self.log_variational_posterior = self.weight.log_prob(weight) + self.bias.log_prob(bias)
        else:
            self.log_prior, self.log_variational_posterior = 0, 0
        # print(input.shape)
        return F.linear(input, weight, bias)

class SimpleConvNet(nn.Module):
    def __init__(self, input_channels, dims = 32, num_classes=10):
        super(type(self), self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(input_channels, 6, kernel_size=5, stride=1),
            #nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        dims = int((dims - 4)/2)
        self.layer2 = nn.Sequential(
            nn.Conv2d(6, 16, kernel_size=5, stride=1),
            #nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2))
        dims = int((dims - 4) / 2)
        self.fc = nn.Linear(16*dims*dims, num_classes)

    def forward(self, x, sample=False, calculate_log_probs=False):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.reshape(out.size(0), -1)
        out = self.fc(out)
        return out

###############
## LeNet - 5 ##
###############

class LeNet5(nn.Module):
    def __init__(self, input_channels, dims = 32, num_classes=10):
        super(type(self), self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(input_channels, 6, 5),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        dims = int((dims-4)/2)
        self.layer2 = nn.Sequential(
            nn.Conv2d(6, 16, 5),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        dims = int((dims-4)/2)
        self.fc1 = nn.Linear(16*dims*dims, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc = nn.Linear(84, num_classes)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.shape[0], -1)
        out = F.relu(self.fc1(out))
        out = F.relu(self.fc2(out))
        out = self.fc(out)
        return out

############################
## Multi-Layer Perceptron ##
############################

class MLP(nn.Module):
    def __init__(self):
        super(type(self), self).__init__()
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 1200)
        self.fc3 = nn.Linear(1200, 10)

    def forward(self, x):
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ## VOGN.py

# %%
import math
import torch
from torch.optim.optimizer import Optimizer
from torch.nn.utils import parameters_to_vector, vector_to_parameters
import torch.nn as nn
import torch.nn.functional as F

#TODO Refactor gradient scaling

################################
## PyTorch Optimizer for VOGN ##
################################
required = object()


def update_input(self, input, output):
    self.input = input[0].data
    self.output = output


class VOGN(Optimizer):
    """Implements the VOGN algorithm. It uses the Generalized Gauss Newton (GGN)
        approximation to the Hessian and a mean-field approximation. Note that this
        optimizer does **not** support multiple model parameter groups. All model
        parameters must use the same optimizer parameters.
        model (nn.Module): network model
        train_set_size (int): number of data points in the full training set
            (objective assumed to be on the form (1/M)*sum(-log p))
        lr (float, optional): learning rate (default: 1e-3)
        betas (Tuple[float, float], optional): coefficients used for computing
            running average of gradients and sum of squared gradient (default: 0.999)
        prior_mu (FloatTensor, optional): mu of prior distribution (posterior of previous task)
            (default: None)
        prior_prec (float or FloatTensor, optional): prior precision on parameters
            (default: 1.0)
        prec_init (float, optional): initial precision for variational dist. q
            (default: 1.0)
        num_samples (float, optional): number of MC samples
            (default: 1)
    """

    def __init__(self, model, train_set_size, lr=1e-3, betas=(0.9, 0.999), prior_mu=None, prior_prec=1.0,
                 initial_prec=1.0, num_samples=1):
        if lr <= 0.0:
            raise ValueError("Invalid learning rate: {}".format(lr))
        if prior_mu is not None and not torch.is_tensor(prior_mu):
            raise ValueError("Invalid prior mu value (from previous task): {}".format(prior_mu))
        if torch.is_tensor(prior_prec):
            if (prior_prec < 0.0).all():
                raise ValueError("Invalid prior precision tensor: {}".format(prior_prec))
        else:
            if prior_prec < 0.0:
                raise ValueError("Invalid prior precision value: {}".format(prior_prec))
        if torch.is_tensor(initial_prec):
            if (initial_prec < 0.0).all():
                raise ValueError("Invalid initial precision tensor: {}".format(initial_prec))
        else:
            if initial_prec < 0.0:
                raise ValueError("Invalid initial precision value: {}".format(initial_prec))
        if not 0.0 <= betas[0] < 1.0:
            raise ValueError("Invalid beta parameter at index 0: {}".format(betas[0]))
        if not 0.0 <= betas[1] < 1.0:
            raise ValueError("Invalid beta parameter at index 1: {}".format(betas[1]))
        if num_samples < 1:
            raise ValueError("Invalid num_samples parameter: {}".format(num_samples))
        if train_set_size < 1:
            raise ValueError("Invalid number of training data points: {}".format(train_set_size))

        defaults = dict(lr=lr, betas=betas, prior_mu=prior_mu, prior_prec=prior_prec, initial_prec=initial_prec,
                        num_samples=num_samples, train_set_size=train_set_size)
        super(VOGN, self).__init__(model.parameters(), defaults)

        self.train_modules = []
        self.set_train_modules(model)
        for module in self.train_modules:
            module.register_forward_hook(update_input)

        defaults = self.defaults
        # We only support a single parameter group.
        parameters = self.param_groups[0]['params']
        device = parameters[0].device

        p = parameters_to_vector(parameters)
        # mean parameter of variational distribution.
        self.state['mu'] = p.clone().detach()

        # mean parameter of prior distribution.
        if torch.is_tensor(defaults['prior_mu']):
            self.state['prior_mu'] = defaults['prior_mu'].to(device)
        else:
            self.state['prior_mu'] = torch.zeros_like(p, device=device)

        # covariance parameter of variational distribution -- saved as a diagonal precision matrix.
        if torch.is_tensor(defaults['initial_prec']):
            self.state['precision'] = defaults['initial_prec'].to(device)
        else:
            self.state['precision'] = torch.ones_like(p, device=device) * defaults['initial_prec']

        # covariance parameter of prior distribution -- saved as a diagonal precision matrix.
        if torch.is_tensor(defaults['prior_prec']):
            self.state['prior_prec'] = defaults['prior_prec'].to(device)
        else:
            self.state['prior_prec'] = torch.ones_like(p, device=device) * defaults['prior_prec']

        self.state['momentum'] = torch.zeros_like(p, device=device)

    def set_train_modules(self, module):
        if len(list(module.children())) == 0:
            if len(list(module.parameters())) != 0:
                self.train_modules.append(module)
        else:
            for child in list(module.children()):
                self.set_train_modules(child)

    def step(self, closure):
        """Performs a single optimization step.
        Arguments:
            closure (callable): A closure that reevaluates the model
                and returns the loss without doing the backward pass
        """

        if closure is None:
            raise RuntimeError(
                'For now, VOGN only supports that the model/loss can be reevaluated inside the step function')

        defaults = self.defaults
        # We only support a single parameter group.
        parameters = self.param_groups[0]['params']
        lr = self.param_groups[0]['lr']
        momentum_beta = defaults['betas'][0]
        beta = defaults['betas'][1]
        momentum = self.state['momentum']

        mu = self.state['mu']
        precision = self.state['precision']
        prior_mu = self.state['prior_mu']
        prior_prec = self.state['prior_prec']

        grad_hat = torch.zeros_like(mu)
        ggn_hat = torch.zeros_like(mu)

        loss_list = []
        pred_list = []
        for _ in range(defaults['num_samples']):
            # Sample a parameter vector:
            raw_noise = torch.normal(mean=torch.zeros_like(mu), std=1.0)
            p = torch.addcdiv(mu, 1., raw_noise, torch.sqrt(precision))
            vector_to_parameters(p, parameters)

            # Get loss and predictions
            loss, preds = closure()
            pred_list.append(preds)

            lc = []
            # Store the linear combinations
            for module in self.train_modules:
                lc.append(module.output)

            linear_grad = torch.autograd.grad(loss, lc)
            loss_list.append(loss.detach())

            grad = []
            ggn = []
            for i, module in enumerate(self.train_modules):
                G = linear_grad[i]
                A = module.input.clone().detach()
                M = A.shape[0]
                G *= M
                G2 = torch.mul(G, G)

                if isinstance(module, nn.Linear):
                    A2 = torch.mul(A, A)
                    grad.append(torch.einsum('ij,ik->jk', G, A))
                    ggn.append(torch.einsum('ij, ik->jk', G2, A2))
                    if module.bias is not None:
                        grad.append(torch.einsum('ij->j', G))
                        ggn.append(torch.einsum('ij->j', G2))

                if isinstance(module, nn.Conv2d):
                    A = F.unfold(A, kernel_size=module.kernel_size, dilation=module.dilation, padding=module.padding,
                                 stride=module.stride)
                    A2 = torch.mul(A, A)
                    _, k, hw = A.shape
                    _, c, _, _ = G.shape
                    G = G.view(M, c, -1)
                    G2 = G2.view(M, c, -1)
                    grad.append(torch.einsum('ijl,ikl->jk', G, A))
                    ggn.append(torch.einsum('ijl,ikl->jk', G2, A2))
                    if module.bias is not None:
                        A = torch.ones((M, 1, hw), device=A.device)
                        grad.append(torch.einsum('ijl,ikl->jk', G, A))
                        ggn.append(torch.einsum('ijl,ikl->jk', G2, A))

                if isinstance(module, nn.BatchNorm1d):
                    A2 = torch.mul(A, A)
                    grad.append(torch.einsum('ij->j', torch.mul(G, A)))
                    ggn.append(torch.einsum('ij->j', torch.mul(G2, A2)))
                    if module.bias is not None:
                        grad.append(torch.einsum('ij->j', G))
                        ggn.append(torch.einsum('ij->j', G2))

                if isinstance(module, nn.BatchNorm2d):
                    A2 = torch.mul(A, A)
                    grad.append(torch.einsum('ijkl->j', torch.mul(G, A)))
                    ggn.append(torch.einsum('ijkl->j', torch.mul(G2, A2)))
                    if module.bias is not None:
                        grad.append(torch.einsum('ijkl->j', G))
                        ggn.append(torch.einsum('ijkl->j', G2))

            grad = parameters_to_vector(grad).div(M).detach()
            ggn = parameters_to_vector(ggn).div(M).detach()

            grad_hat.add_(grad)
            ggn_hat.add_(ggn)

        # Convert the parameter gradient to a single vector.
        grad_hat = grad_hat.mul(defaults['train_set_size'] / defaults['num_samples'])
        ggn_hat.mul_(defaults['train_set_size'] / defaults['num_samples'])

        # Add momentum
        momentum.mul_(momentum_beta).add_((1 - momentum_beta), grad_hat)

        # Get the mean loss over the number of samples
        loss = torch.mean(torch.stack(loss_list))

        # Update precision matrix
        precision.mul_(beta).add_((1 - beta), ggn_hat + prior_prec)
        # Update mean vector
        mu.addcdiv_(-lr, momentum + torch.mul(mu - prior_mu, prior_prec), precision)
        # Update model parameters
        vector_to_parameters(self.state['mu'], self.param_groups[0]['params'])

        return loss, pred_list

    def get_distribution_params(self):
        """Returns current mean and precision of variational distribution
           (usually used to save parameters from current task as prior for next task).
        """
        mu = self.state['mu'].clone().detach()
        precision = self.state['precision'].clone().detach()

        return mu, precision

    def get_mc_predictions(self, forward_function, inputs, ret_numpy=False, raw_noises=None, *args, **kwargs):
        """Returns Monte Carlo predictions.
        Arguments:
            forward_function (callable): The forward function of the model
                that takes inputs and returns the outputs.
            inputs (FloatTensor): The inputs to the model.
            mc_samples (int): The number of Monte Carlo samples.
            ret_numpy (bool): If true, the returned list contains numpy arrays,
                otherwise it contains torch tensors.
        """

        # We only support a single parameter group.
        parameters = self.param_groups[0]['params']
        predictions = []
        precision = self.state['precision']
        mu = self.state['mu']
        if raw_noises is None:
            raw_noises = [torch.zeros_like(mu)]
        for raw_noise in raw_noises:
            # Sample a parameter vector:
            # raw_noise = torch.normal(mean=torch.zeros_like(mu), std=1.0)

            p = torch.addcdiv(mu, 1., raw_noise, torch.sqrt(precision))
            vector_to_parameters(p, parameters)

            # Call the forward computation function
            outputs = forward_function(inputs, *args, **kwargs)
            if ret_numpy:
                outputs = outputs.data.cpu().numpy()
            predictions.append(outputs)
        vector_to_parameters(self.state['mu'], self.param_groups[0]['params'])
        return predictions

    def _kl_gaussian(self, p_mu, p_sigma, q_mu, q_sigma):
        log_std_diff = torch.sum(torch.log(p_sigma ** 2) - torch.log(q_sigma ** 2))
        mu_diff_term = torch.sum((q_sigma ** 2 + (p_mu - q_mu) ** 2) / p_sigma ** 2)
        const = list(q_mu.size())[0]
        
        return 0.5 * (mu_diff_term - const + log_std_diff)

    def kl_divergence(self):
        prec0 = self.state['prior_prec']
        prec = self.state['precision']
        mu = self.state['mu']
        sigma = 1. / torch.sqrt(prec)
        mu0 = self.state['prior_mu']
        if torch.is_tensor(prec0):
            sigma0 = 1. / torch.sqrt(prec0)
        else:
            sigma0 = 1. / math.sqrt(prec0)
        kl = self._kl_gaussian(p_mu=mu0, p_sigma=sigma0, q_mu=mu, q_sigma=sigma)
        
        return kl

# %% [markdown]
# ## utils.py

# %%
MODEL_NO = 1

# %%
import torch
import torch.nn.functional as F
use_cuda = torch.cuda.is_available()

def softmax_predictive_accuracy(logits_list, y, ret_loss = False):
    probs_list = [F.log_softmax(logits, dim=1) for logits in logits_list]
    probs_tensor = torch.stack(probs_list, dim = 2)
    probs = torch.mean(probs_tensor, dim=2)
    if ret_loss:
        loss = F.nll_loss(probs, y, reduction='sum').item()
    _, pred_class = torch.max(probs, 1)
    correct = pred_class.eq(y.view_as(pred_class)).sum().item()
    if ret_loss:
        return correct, loss
    return correct

def train_model(model, dataloaders, criterion, optimizer, num_epochs=25, test_samples=100):
    """
    Performs Training and Validation on test set on the given model using the specified optimizer
    :param model: (nn.Module) Model to be trained
    :param dataloaders: (list) train and test dataloaders
    :param criterion: Loss Function
    :param optimizer: Optimizer to be used for training
    :param num_epochs: Number of epochs to train the model
    :return: trained model, test and train metric history
    """
    train_loss_history = []
    train_accuracy_history = []
    test_accuracy_history = []
    test_loss_history = []
    trainloader, testloader = dataloaders

    for epoch in range(num_epochs):
        model.train(True)
        print('Epoch[%d]:' % epoch)
        running_train_loss = 0.
        running_train_correct = 0.
        for i, data in enumerate(trainloader):
            inputs, labels = data
            if use_cuda:
                inputs, labels = inputs.cuda(), labels.cuda()
            if isinstance(optimizer, VOGN):
                def closure():
                    optimizer.zero_grad()
                    logits = model.forward(inputs)
                    loss = criterion(logits, labels)
                    return loss, logits
            else:
                def closure():
                    optimizer.zero_grad()
                    logits = model.forward(inputs)
                    loss = criterion(logits, labels)
                    loss.backward()
                    return loss, logits
            loss, logits = optimizer.step(closure)
            running_train_loss += loss.detach().item() * inputs.shape[0]
            if isinstance(optimizer, VOGN):
                running_train_correct += softmax_predictive_accuracy(logits, labels)

            else:
                _pred = logits.argmax(dim=1, keepdim=True)
                running_train_correct += _pred.eq(labels.view_as(_pred)).sum().item()
            # Print Training Progress
            if i%200 == 199:
                train_accuracy = running_train_correct / (i*inputs.shape[0])
                print('Iteration[%d]: Train Loss: %f   Train Accuracy: %f ' % (i+1, running_train_loss/(i*inputs.shape[0]), train_accuracy))

        train_accuracy = 100 * running_train_correct / len(trainloader.dataset)
        train_loss = running_train_loss / len(trainloader.dataset)

        model.eval()
        test_loss = 0
        total_correct = 0
        device = 'cuda' if use_cuda else 'cpu'
        with torch.no_grad():
            for data, target in testloader:
                data, target = data.to(device), target.to(device)

                if optimizer is not None and isinstance(optimizer, VOGN):
                    raw_noises = []
                    for mc_sample in range(test_samples):
                        raw_noises.append(torch.normal(mean=torch.zeros_like(optimizer.state['mu']), std=1.0))
                    outputs = optimizer.get_mc_predictions(model, data,
                                                          raw_noises=raw_noises)
                    correct, loss = softmax_predictive_accuracy(outputs, target, ret_loss=True)
                    total_correct += correct
                    test_loss += loss

                else:
                    output = model(data)
                    test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
                    pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
                    total_correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(testloader.dataset)
        test_accuracy = 100. * total_correct / len(testloader.dataset)

        train_accuracy_history.append(train_accuracy)
        train_loss_history.append(train_loss)
        test_accuracy_history.append(test_accuracy)
        test_loss_history.append(test_loss)
        print('## Epoch[%d], Train Loss: %f   &   Train Accuracy: %f' % (epoch, train_loss, train_accuracy))
        print('## Epoch[%d], Test Loss: %f   &   Test Accuracy: %f' % (epoch, test_loss, test_accuracy))

        model_save_name = 'MNIST_model{}_epoch{}'.format(MODEL_NO, epoch)    
        path = "/content/gdrive/My Drive/CS7643ModelsTesting/MNISTModels/{}".format(model_save_name) 
        torch.save(model.state_dict(), path)
        
    return model, train_loss_history, train_accuracy_history, test_loss_history, test_accuracy_history

# %% [markdown]
# ## main.py

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Test wether GPUs are available
use_cuda =  torch.cuda.is_available()
print("Using Cuda: %s" % use_cuda)

# Set Random Seed
torch.manual_seed(42)

# Load the dataset, 'mnist' or 'cifar10'
dataset = 'mnist'
data = Dataset(dataset)
trainloader = data.get_train_loader(batch_size=128)
testloader = data.get_test_loader(batch_size=128)
N = data.get_train_size() # Save the size of the train set
input_channels = 1
dims = 28

total_ensembles = 5
# Out:
# Using Cuda: True
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
MODEL_NO = 1
net_ensemble = []
for num_ensembles in range(total_ensembles):
  # Initilaize the model, criterion and optimizer
  model = SimpleConvNet(input_channels=input_channels, dims=dims)

  model.layer1[0].weight = nn.Parameter((torch.rand(((model.layer1[0].weight.shape))) - 0.5)/2)
  model.layer2[0].weight = nn.Parameter((torch.rand(((model.layer2[0].weight.shape))) - 0.5)/2)
  model.fc.weight = nn.Parameter((torch.rand(((model.fc.weight.shape))) - 0.5)/2)

  if use_cuda:
    model = model.cuda()
  criterion = nn.CrossEntropyLoss()
  optimizer = VOGN(model, train_set_size=N, initial_prec=1e2, num_samples=10)
  #optimizer = optim.Adam(model.parameters())
  model, train_loss, train_accuracy, test_loss, test_accuracy = train_model(model, [trainloader, testloader], criterion,
                                                                          optimizer, num_epochs=50)
  
  net_ensemble.append(model)

  MODEL_NO += 1
  # Plot the results
  fig, ax = plt.subplots()
  ax.plot(train_loss, 'b')
  ax.plot(test_loss, 'g')
  ax.legend(["Train Loss", "Test Loss"])
  plt.ylabel("Log Loss")
  plt.xlabel("Epochs")
  plt.show()

  fig, ax = plt.subplots()
  ax.plot(train_accuracy, 'b')
  ax.plot(test_accuracy, 'g')
  ax.legend(["Train Accuracy", "Test Accuracy"])
  plt.ylabel("Accuracy")
  plt.xlabel("Epochs")
  plt.show()
# Out:
# Epoch[0]:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Iteration[200]: Train Loss: 0.807957   Train Accuracy: 0.757381
# Iteration[400]: Train Loss: 0.521034   Train Accuracy: 0.847509
# ## Epoch[0], Train Loss: 0.472552   &   Train Accuracy: 86.038333
# ## Epoch[0], Test Loss: 0.159653   &   Test Accuracy: 95.860000
# Epoch[1]:
# Iteration[200]: Train Loss: 0.164467   Train Accuracy: 0.962743
# Iteration[400]: Train Loss: 0.157191   Train Accuracy: 0.961897
# ## Epoch[1], Train Loss: 0.153465   &   Train Accuracy: 96.055000
# ## Epoch[1], Test Loss: 0.119217   &   Test Accuracy: 96.930000
# Epoch[2]:
# Iteration[200]: Train Loss: 0.124468   Train Accuracy: 0.972166
# Iteration[400]: Train Loss: 0.121262   Train Accuracy: 0.970884
# ## Epoch[2], Train Loss: 0.118680   &   Train Accuracy: 96.926667
# ## Epoch[2], Test Loss: 0.095785   &   Test Accuracy: 97.500000
# Epoch[3]:
# Iteration[200]: Train Loss: 0.102862   Train Accuracy: 0.980253
# Iteration[400]: Train Loss: 0.101451   Train Accuracy: 0.977444
# ## Epoch[3], Train Loss: 0.100715   &   Train Accuracy: 97.490000
# ## Epoch[3], Test Loss: 0.085108   &   Test Accuracy: 97.890000
# Epoch[4]:
# Iteration[200]: Train Loss: 0.090032   Train Accuracy: 0.982765
# Iteration[400]: Train Loss: 0.090107   Train Accuracy: 0.980224
# ## Epoch[4], Train Loss: 0.089577   &   Train Accuracy: 97.768333
# ## Epoch[4], Test Loss: 0.078077   &   Test Accuracy: 97.990000
# Epoch[5]:
# Iteration[200]: Train Loss: 0.078512   Train Accuracy: 0.985867
# Iteration[400]: Train Loss: 0.081358   Train Accuracy: 0.982495
# ## Epoch[5], Train Loss: 0.081551   &   Train Accuracy: 97.993333
# ## Epoch[5], Test Loss: 0.072086   &   Test Accuracy: 98.210000
# Epoch[6]:
# Iteration[200]: Train Loss: 0.078373   Train Accuracy: 0.986416
# Iteration[400]: Train Loss: 0.076525   Train Accuracy: 0.983788
# ## Epoch[6], Train Loss: 0.075840   &   Train Accuracy: 98.173333
# ## Epoch[6], Test Loss: 0.067420   &   Test Accuracy: 98.270000
# Epoch[7]:
# Iteration[200]: Train Loss: 0.075370   Train Accuracy: 0.987005
# Iteration[400]: Train Loss: 0.071533   Train Accuracy: 0.985021
# ## Epoch[7], Train Loss: 0.072113   &   Train Accuracy: 98.258333
# ## Epoch[7], Test Loss: 0.065634   &   Test Accuracy: 98.350000
# Epoch[8]:
# Iteration[200]: Train Loss: 0.065331   Train Accuracy: 0.989282
# Iteration[400]: Train Loss: 0.069618   Train Accuracy: 0.985726
# ## Epoch[8], Train Loss: 0.068515   &   Train Accuracy: 98.353333
# ## Epoch[8], Test Loss: 0.067636   &   Test Accuracy: 98.340000
# Epoch[9]:
# Iteration[200]: Train Loss: 0.065137   Train Accuracy: 0.989400
# Iteration[400]: Train Loss: 0.065516   Train Accuracy: 0.987038
# ## Epoch[9], Train Loss: 0.065639   &   Train Accuracy: 98.461667
# ## Epoch[9], Test Loss: 0.061254   &   Test Accuracy: 98.500000
# Epoch[10]:
# Iteration[200]: Train Loss: 0.061282   Train Accuracy: 0.990892
# Iteration[400]: Train Loss: 0.062627   Train Accuracy: 0.988134
# ## Epoch[10], Train Loss: 0.062927   &   Train Accuracy: 98.555000
# ## Epoch[10], Test Loss: 0.061898   &   Test Accuracy: 98.570000
# Epoch[11]:
# Iteration[200]: Train Loss: 0.061198   Train Accuracy: 0.991206
# Iteration[400]: Train Loss: 0.060313   Train Accuracy: 0.988722
# ## Epoch[11], Train Loss: 0.060880   &   Train Accuracy: 98.590000
# ## Epoch[11], Test Loss: 0.059235   &   Test Accuracy: 98.500000
# Epoch[12]:
# Iteration[200]: Train Loss: 0.058604   Train Accuracy: 0.991442
# Iteration[400]: Train Loss: 0.059593   Train Accuracy: 0.988937
# ## Epoch[12], Train Loss: 0.058754   &   Train Accuracy: 98.666667
# ## Epoch[12], Test Loss: 0.059566   &   Test Accuracy: 98.550000
# Epoch[13]:
# Iteration[200]: Train Loss: 0.055001   Train Accuracy: 0.992462
# Iteration[400]: Train Loss: 0.056797   Train Accuracy: 0.989760
# ## Epoch[13], Train Loss: 0.057781   &   Train Accuracy: 98.713333
# ## Epoch[13], Test Loss: 0.058883   &   Test Accuracy: 98.620000
# Epoch[14]:
# Iteration[200]: Train Loss: 0.055873   Train Accuracy: 0.992933
# Iteration[400]: Train Loss: 0.056451   Train Accuracy: 0.990092
# ## Epoch[14], Train Loss: 0.056497   &   Train Accuracy: 98.745000
# ## Epoch[14], Test Loss: 0.059186   &   Test Accuracy: 98.560000
# Epoch[15]:
# Iteration[200]: Train Loss: 0.054751   Train Accuracy: 0.993287
# Iteration[400]: Train Loss: 0.056468   Train Accuracy: 0.990034
# ## Epoch[15], Train Loss: 0.055316   &   Train Accuracy: 98.788333
# ## Epoch[15], Test Loss: 0.058918   &   Test Accuracy: 98.610000
# Epoch[16]:
# Iteration[200]: Train Loss: 0.051449   Train Accuracy: 0.994111
# Iteration[400]: Train Loss: 0.054614   Train Accuracy: 0.990817
# ## Epoch[16], Train Loss: 0.055999   &   Train Accuracy: 98.826667
# ## Epoch[16], Test Loss: 0.058683   &   Test Accuracy: 98.670000
# Epoch[17]:
# Iteration[200]: Train Loss: 0.051241   Train Accuracy: 0.993562
# Iteration[400]: Train Loss: 0.052903   Train Accuracy: 0.990621
# ## Epoch[17], Train Loss: 0.052917   &   Train Accuracy: 98.811667
# ## Epoch[17], Test Loss: 0.057088   &   Test Accuracy: 98.640000
# Epoch[18]:
# Iteration[200]: Train Loss: 0.051163   Train Accuracy: 0.993640
# Iteration[400]: Train Loss: 0.051832   Train Accuracy: 0.990934
# ## Epoch[18], Train Loss: 0.052005   &   Train Accuracy: 98.850000
# ## Epoch[18], Test Loss: 0.059781   &   Test Accuracy: 98.600000
# Epoch[19]:
# Iteration[200]: Train Loss: 0.051225   Train Accuracy: 0.993522
# Iteration[400]: Train Loss: 0.050358   Train Accuracy: 0.991522
# ## Epoch[19], Train Loss: 0.051002   &   Train Accuracy: 98.880000
# ## Epoch[19], Test Loss: 0.058115   &   Test Accuracy: 98.660000
# Epoch[20]:
# Iteration[200]: Train Loss: 0.047909   Train Accuracy: 0.994543
# Iteration[400]: Train Loss: 0.050262   Train Accuracy: 0.991581
# ## Epoch[20], Train Loss: 0.050632   &   Train Accuracy: 98.890000
# ## Epoch[20], Test Loss: 0.058190   &   Test Accuracy: 98.640000
# Epoch[21]:
# Iteration[200]: Train Loss: 0.048881   Train Accuracy: 0.994936
# Iteration[400]: Train Loss: 0.049071   Train Accuracy: 0.992207
# ## Epoch[21], Train Loss: 0.049417   &   Train Accuracy: 98.961667
# ## Epoch[21], Test Loss: 0.057794   &   Test Accuracy: 98.650000
# Epoch[22]:
# Iteration[200]: Train Loss: 0.050864   Train Accuracy: 0.994504
# Iteration[400]: Train Loss: 0.048706   Train Accuracy: 0.992129
# ## Epoch[22], Train Loss: 0.049195   &   Train Accuracy: 98.951667
# ## Epoch[22], Test Loss: 0.056852   &   Test Accuracy: 98.680000
# Epoch[23]:
# Iteration[200]: Train Loss: 0.046674   Train Accuracy: 0.995210
# Iteration[400]: Train Loss: 0.047578   Train Accuracy: 0.992090
# ## Epoch[23], Train Loss: 0.048370   &   Train Accuracy: 98.961667
# ## Epoch[23], Test Loss: 0.060054   &   Test Accuracy: 98.540000
# Epoch[24]:
# Iteration[200]: Train Loss: 0.045261   Train Accuracy: 0.995328
# Iteration[400]: Train Loss: 0.046228   Train Accuracy: 0.992383
# ## Epoch[24], Train Loss: 0.047415   &   Train Accuracy: 98.958333
# ## Epoch[24], Test Loss: 0.059479   &   Test Accuracy: 98.640000
# Epoch[25]:
# Iteration[200]: Train Loss: 0.046914   Train Accuracy: 0.995250
# Iteration[400]: Train Loss: 0.046315   Train Accuracy: 0.992520
# ## Epoch[25], Train Loss: 0.047253   &   Train Accuracy: 98.985000
# ## Epoch[25], Test Loss: 0.059611   &   Test Accuracy: 98.660000
# Epoch[26]:
# Iteration[200]: Train Loss: 0.047070   Train Accuracy: 0.995210
# Iteration[400]: Train Loss: 0.046726   Train Accuracy: 0.992462
# ## Epoch[26], Train Loss: 0.046295   &   Train Accuracy: 99.020000
# ## Epoch[26], Test Loss: 0.058256   &   Test Accuracy: 98.630000
# Epoch[27]:
# Iteration[200]: Train Loss: 0.049609   Train Accuracy: 0.994661
# Iteration[400]: Train Loss: 0.046752   Train Accuracy: 0.992814
# ## Epoch[27], Train Loss: 0.046343   &   Train Accuracy: 99.045000
# ## Epoch[27], Test Loss: 0.058677   &   Test Accuracy: 98.660000
# Epoch[28]:
# Iteration[200]: Train Loss: 0.044399   Train Accuracy: 0.995839
# Iteration[400]: Train Loss: 0.046545   Train Accuracy: 0.992814
# ## Epoch[28], Train Loss: 0.045640   &   Train Accuracy: 99.035000
# ## Epoch[28], Test Loss: 0.061079   &   Test Accuracy: 98.600000
# Epoch[29]:
# Iteration[200]: Train Loss: 0.044646   Train Accuracy: 0.995721
# Iteration[400]: Train Loss: 0.044932   Train Accuracy: 0.993441
# ## Epoch[29], Train Loss: 0.044523   &   Train Accuracy: 99.090000
# ## Epoch[29], Test Loss: 0.057804   &   Test Accuracy: 98.740000
# Epoch[30]:
# Iteration[200]: Train Loss: 0.042457   Train Accuracy: 0.995839
# Iteration[400]: Train Loss: 0.044291   Train Accuracy: 0.993401
# ## Epoch[30], Train Loss: 0.044585   &   Train Accuracy: 99.068333
# ## Epoch[30], Test Loss: 0.057648   &   Test Accuracy: 98.690000
# Epoch[31]:
# Iteration[200]: Train Loss: 0.046337   Train Accuracy: 0.995682
# Iteration[400]: Train Loss: 0.044390   Train Accuracy: 0.993401
# ## Epoch[31], Train Loss: 0.043645   &   Train Accuracy: 99.103333
# ## Epoch[31], Test Loss: 0.059321   &   Test Accuracy: 98.730000
# Epoch[32]:
# Iteration[200]: Train Loss: 0.043278   Train Accuracy: 0.995996
# Iteration[400]: Train Loss: 0.044194   Train Accuracy: 0.993499
# ## Epoch[32], Train Loss: 0.043988   &   Train Accuracy: 99.101667
# ## Epoch[32], Test Loss: 0.059304   &   Test Accuracy: 98.710000
# Epoch[33]:
# Iteration[200]: Train Loss: 0.043307   Train Accuracy: 0.995524
# Iteration[400]: Train Loss: 0.043305   Train Accuracy: 0.993284
# ## Epoch[33], Train Loss: 0.043489   &   Train Accuracy: 99.073333
# ## Epoch[33], Test Loss: 0.058988   &   Test Accuracy: 98.670000
# Epoch[34]:
# Iteration[200]: Train Loss: 0.043577   Train Accuracy: 0.995839
# Iteration[400]: Train Loss: 0.042748   Train Accuracy: 0.993460
# ## Epoch[34], Train Loss: 0.042781   &   Train Accuracy: 99.095000
# ## Epoch[34], Test Loss: 0.058588   &   Test Accuracy: 98.700000
# Epoch[35]:
# Iteration[200]: Train Loss: 0.039100   Train Accuracy: 0.997644
# Iteration[400]: Train Loss: 0.041595   Train Accuracy: 0.994224
# ## Epoch[35], Train Loss: 0.042639   &   Train Accuracy: 99.143333
# ## Epoch[35], Test Loss: 0.058896   &   Test Accuracy: 98.740000
# Epoch[36]:
# Iteration[200]: Train Loss: 0.044109   Train Accuracy: 0.996270
# Iteration[400]: Train Loss: 0.042559   Train Accuracy: 0.993950
# ## Epoch[36], Train Loss: 0.042872   &   Train Accuracy: 99.136667
# ## Epoch[36], Test Loss: 0.057991   &   Test Accuracy: 98.790000
# Epoch[37]:
# Iteration[200]: Train Loss: 0.041029   Train Accuracy: 0.997095
# Iteration[400]: Train Loss: 0.041923   Train Accuracy: 0.994048
# ## Epoch[37], Train Loss: 0.042152   &   Train Accuracy: 99.145000
# ## Epoch[37], Test Loss: 0.060015   &   Test Accuracy: 98.700000
# Epoch[38]:
# Iteration[200]: Train Loss: 0.041824   Train Accuracy: 0.996899
# Iteration[400]: Train Loss: 0.041918   Train Accuracy: 0.994165
# ## Epoch[38], Train Loss: 0.042299   &   Train Accuracy: 99.143333
# ## Epoch[38], Test Loss: 0.059490   &   Test Accuracy: 98.740000
# Epoch[39]:
# Iteration[200]: Train Loss: 0.040639   Train Accuracy: 0.997016
# Iteration[400]: Train Loss: 0.041529   Train Accuracy: 0.994008
# ## Epoch[39], Train Loss: 0.041963   &   Train Accuracy: 99.136667
# ## Epoch[39], Test Loss: 0.059374   &   Test Accuracy: 98.720000
# Epoch[40]:
# Iteration[200]: Train Loss: 0.039872   Train Accuracy: 0.996977
# Iteration[400]: Train Loss: 0.040384   Train Accuracy: 0.994341
# ## Epoch[40], Train Loss: 0.040516   &   Train Accuracy: 99.166667
# ## Epoch[40], Test Loss: 0.061671   &   Test Accuracy: 98.630000
# Epoch[41]:
# Iteration[200]: Train Loss: 0.040646   Train Accuracy: 0.996624
# Iteration[400]: Train Loss: 0.040647   Train Accuracy: 0.994048
# ## Epoch[41], Train Loss: 0.041274   &   Train Accuracy: 99.151667
# ## Epoch[41], Test Loss: 0.060126   &   Test Accuracy: 98.790000
# Epoch[42]:
# Iteration[200]: Train Loss: 0.041506   Train Accuracy: 0.997056
# Iteration[400]: Train Loss: 0.040778   Train Accuracy: 0.994615
# ## Epoch[42], Train Loss: 0.040971   &   Train Accuracy: 99.213333
# ## Epoch[42], Test Loss: 0.059230   &   Test Accuracy: 98.670000
# Epoch[43]:
# Iteration[200]: Train Loss: 0.039886   Train Accuracy: 0.997252
# Iteration[400]: Train Loss: 0.040775   Train Accuracy: 0.994400
# ## Epoch[43], Train Loss: 0.041167   &   Train Accuracy: 99.175000
# ## Epoch[43], Test Loss: 0.060650   &   Test Accuracy: 98.670000
# Epoch[44]:
# Iteration[200]: Train Loss: 0.038938   Train Accuracy: 0.997684
# Iteration[400]: Train Loss: 0.040571   Train Accuracy: 0.994968
# ## Epoch[44], Train Loss: 0.040234   &   Train Accuracy: 99.236667
# ## Epoch[44], Test Loss: 0.059670   &   Test Accuracy: 98.720000
# Epoch[45]:
# Iteration[200]: Train Loss: 0.043074   Train Accuracy: 0.996035
# Iteration[400]: Train Loss: 0.039564   Train Accuracy: 0.994400
# ## Epoch[45], Train Loss: 0.039731   &   Train Accuracy: 99.185000
# ## Epoch[45], Test Loss: 0.059543   &   Test Accuracy: 98.670000
# Epoch[46]:
# Iteration[200]: Train Loss: 0.039000   Train Accuracy: 0.997370
# Iteration[400]: Train Loss: 0.039706   Train Accuracy: 0.994635
# ## Epoch[46], Train Loss: 0.039919   &   Train Accuracy: 99.206667
# ## Epoch[46], Test Loss: 0.062495   &   Test Accuracy: 98.590000
# Epoch[47]:
# Iteration[200]: Train Loss: 0.039956   Train Accuracy: 0.997252
# Iteration[400]: Train Loss: 0.039814   Train Accuracy: 0.994694
# ## Epoch[47], Train Loss: 0.040050   &   Train Accuracy: 99.208333
# ## Epoch[47], Test Loss: 0.060670   &   Test Accuracy: 98.650000
# Epoch[48]:
# Iteration[200]: Train Loss: 0.039223   Train Accuracy: 0.996859
# Iteration[400]: Train Loss: 0.039818   Train Accuracy: 0.994439
# ## Epoch[48], Train Loss: 0.039492   &   Train Accuracy: 99.205000
# ## Epoch[48], Test Loss: 0.062312   &   Test Accuracy: 98.650000
# Epoch[49]:
# Iteration[200]: Train Loss: 0.038334   Train Accuracy: 0.997173
# Iteration[400]: Train Loss: 0.040961   Train Accuracy: 0.994204
# ## Epoch[49], Train Loss: 0.040404   &   Train Accuracy: 99.185000
# ## Epoch[49], Test Loss: 0.061820   &   Test Accuracy: 98.590000
# Epoch[0]:
# Iteration[200]: Train Loss: 1.154707   Train Accuracy: 0.642431
# Iteration[400]: Train Loss: 0.689963   Train Accuracy: 0.792195
# ## Epoch[0], Train Loss: 0.612535   &   Train Accuracy: 81.443333
# ## Epoch[0], Test Loss: 0.156171   &   Test Accuracy: 95.990000
# Epoch[1]:
# Iteration[200]: Train Loss: 0.149716   Train Accuracy: 0.965963
# Iteration[400]: Train Loss: 0.139175   Train Accuracy: 0.966537
# ## Epoch[1], Train Loss: 0.134688   &   Train Accuracy: 96.513333
# ## Epoch[1], Test Loss: 0.111755   &   Test Accuracy: 97.160000
# Epoch[2]:
# Iteration[200]: Train Loss: 0.108181   Train Accuracy: 0.977191
# Iteration[400]: Train Loss: 0.105931   Train Accuracy: 0.975818
# ## Epoch[2], Train Loss: 0.103439   &   Train Accuracy: 97.398333
# ## Epoch[2], Test Loss: 0.092099   &   Test Accuracy: 97.590000
# Epoch[3]:
# Iteration[200]: Train Loss: 0.096069   Train Accuracy: 0.980253
# Iteration[400]: Train Loss: 0.089234   Train Accuracy: 0.979441
# ## Epoch[3], Train Loss: 0.089340   &   Train Accuracy: 97.703333
# ## Epoch[3], Test Loss: 0.080982   &   Test Accuracy: 98.020000
# Epoch[4]:
# Iteration[200]: Train Loss: 0.081666   Train Accuracy: 0.984454
# Iteration[400]: Train Loss: 0.080486   Train Accuracy: 0.982417
# ## Epoch[4], Train Loss: 0.080627   &   Train Accuracy: 97.973333
# ## Epoch[4], Test Loss: 0.074150   &   Test Accuracy: 98.120000
# Epoch[5]:
# Iteration[200]: Train Loss: 0.075574   Train Accuracy: 0.985828
# Iteration[400]: Train Loss: 0.074111   Train Accuracy: 0.984042
# ## Epoch[5], Train Loss: 0.074170   &   Train Accuracy: 98.158333
# ## Epoch[5], Test Loss: 0.070823   &   Test Accuracy: 98.300000
# Epoch[6]:
# Iteration[200]: Train Loss: 0.069104   Train Accuracy: 0.988065
# Iteration[400]: Train Loss: 0.069321   Train Accuracy: 0.985726
# ## Epoch[6], Train Loss: 0.069113   &   Train Accuracy: 98.335000
# ## Epoch[6], Test Loss: 0.069504   &   Test Accuracy: 98.250000
# Epoch[7]:
# Iteration[200]: Train Loss: 0.068738   Train Accuracy: 0.988929
# Iteration[400]: Train Loss: 0.064631   Train Accuracy: 0.987234
# ## Epoch[7], Train Loss: 0.064653   &   Train Accuracy: 98.445000
# ## Epoch[7], Test Loss: 0.068338   &   Test Accuracy: 98.370000
# Epoch[8]:
# Iteration[200]: Train Loss: 0.059407   Train Accuracy: 0.991324
# Iteration[400]: Train Loss: 0.060987   Train Accuracy: 0.987880
# ## Epoch[8], Train Loss: 0.061938   &   Train Accuracy: 98.525000
# ## Epoch[8], Test Loss: 0.066617   &   Test Accuracy: 98.490000
# Epoch[9]:
# Iteration[200]: Train Loss: 0.059264   Train Accuracy: 0.991442
# Iteration[400]: Train Loss: 0.060083   Train Accuracy: 0.988487
# ## Epoch[9], Train Loss: 0.059486   &   Train Accuracy: 98.630000
# ## Epoch[9], Test Loss: 0.067675   &   Test Accuracy: 98.400000
# Epoch[10]:
# Iteration[200]: Train Loss: 0.060925   Train Accuracy: 0.990539
# Iteration[400]: Train Loss: 0.057523   Train Accuracy: 0.988898
# ## Epoch[10], Train Loss: 0.057375   &   Train Accuracy: 98.648333
# ## Epoch[10], Test Loss: 0.063119   &   Test Accuracy: 98.570000
# Epoch[11]:
# Iteration[200]: Train Loss: 0.053852   Train Accuracy: 0.993993
# Iteration[400]: Train Loss: 0.055672   Train Accuracy: 0.990229
# ## Epoch[11], Train Loss: 0.055291   &   Train Accuracy: 98.770000
# ## Epoch[11], Test Loss: 0.062288   &   Test Accuracy: 98.680000
# Epoch[12]:
# Iteration[200]: Train Loss: 0.051854   Train Accuracy: 0.994150
# Iteration[400]: Train Loss: 0.053168   Train Accuracy: 0.990993
# ## Epoch[12], Train Loss: 0.052987   &   Train Accuracy: 98.846667
# ## Epoch[12], Test Loss: 0.063682   &   Test Accuracy: 98.540000
# Epoch[13]:
# Iteration[200]: Train Loss: 0.051156   Train Accuracy: 0.994111
# Iteration[400]: Train Loss: 0.052185   Train Accuracy: 0.991013
# ## Epoch[13], Train Loss: 0.051914   &   Train Accuracy: 98.858333
# ## Epoch[13], Test Loss: 0.063161   &   Test Accuracy: 98.500000
# Epoch[14]:
# Iteration[200]: Train Loss: 0.051520   Train Accuracy: 0.994150
# Iteration[400]: Train Loss: 0.050322   Train Accuracy: 0.991561
# ## Epoch[14], Train Loss: 0.050389   &   Train Accuracy: 98.908333
# ## Epoch[14], Test Loss: 0.061761   &   Test Accuracy: 98.560000
# Epoch[15]:
# Iteration[200]: Train Loss: 0.049112   Train Accuracy: 0.994700
# Iteration[400]: Train Loss: 0.048779   Train Accuracy: 0.992109
# ## Epoch[15], Train Loss: 0.048909   &   Train Accuracy: 98.958333
# ## Epoch[15], Test Loss: 0.061010   &   Test Accuracy: 98.650000
# Epoch[16]:
# Iteration[200]: Train Loss: 0.048327   Train Accuracy: 0.994739
# Iteration[400]: Train Loss: 0.047679   Train Accuracy: 0.992246
# ## Epoch[16], Train Loss: 0.048058   &   Train Accuracy: 98.956667
# ## Epoch[16], Test Loss: 0.060809   &   Test Accuracy: 98.580000
# Epoch[17]:
# Iteration[200]: Train Loss: 0.048342   Train Accuracy: 0.994307
# Iteration[400]: Train Loss: 0.047154   Train Accuracy: 0.991855
# ## Epoch[17], Train Loss: 0.046915   &   Train Accuracy: 98.945000
# ## Epoch[17], Test Loss: 0.062514   &   Test Accuracy: 98.590000
# Epoch[18]:
# Iteration[200]: Train Loss: 0.045816   Train Accuracy: 0.995250
# Iteration[400]: Train Loss: 0.046030   Train Accuracy: 0.992814
# ## Epoch[18], Train Loss: 0.045669   &   Train Accuracy: 99.023333
# ## Epoch[18], Test Loss: 0.061682   &   Test Accuracy: 98.640000
# Epoch[19]:
# Iteration[200]: Train Loss: 0.043704   Train Accuracy: 0.995956
# Iteration[400]: Train Loss: 0.045486   Train Accuracy: 0.992716
# ## Epoch[19], Train Loss: 0.045452   &   Train Accuracy: 99.011667
# ## Epoch[19], Test Loss: 0.059312   &   Test Accuracy: 98.680000
# Epoch[20]:
# Iteration[200]: Train Loss: 0.043982   Train Accuracy: 0.995603
# Iteration[400]: Train Loss: 0.044388   Train Accuracy: 0.993029
# ## Epoch[20], Train Loss: 0.044614   &   Train Accuracy: 99.066667
# ## Epoch[20], Test Loss: 0.059936   &   Test Accuracy: 98.660000
# Epoch[21]:
# Iteration[200]: Train Loss: 0.046391   Train Accuracy: 0.995171
# Iteration[400]: Train Loss: 0.044352   Train Accuracy: 0.993186
# ## Epoch[21], Train Loss: 0.044615   &   Train Accuracy: 99.053333
# ## Epoch[21], Test Loss: 0.059946   &   Test Accuracy: 98.730000
# Epoch[22]:
# Iteration[200]: Train Loss: 0.044948   Train Accuracy: 0.995171
# Iteration[400]: Train Loss: 0.043054   Train Accuracy: 0.993519
# ## Epoch[22], Train Loss: 0.043499   &   Train Accuracy: 99.093333
# ## Epoch[22], Test Loss: 0.059195   &   Test Accuracy: 98.710000
# Epoch[23]:
# Iteration[200]: Train Loss: 0.045218   Train Accuracy: 0.995721
# Iteration[400]: Train Loss: 0.043034   Train Accuracy: 0.993597
# ## Epoch[23], Train Loss: 0.042881   &   Train Accuracy: 99.108333
# ## Epoch[23], Test Loss: 0.059476   &   Test Accuracy: 98.690000
# Epoch[24]:
# Iteration[200]: Train Loss: 0.039051   Train Accuracy: 0.997605
# Iteration[400]: Train Loss: 0.041014   Train Accuracy: 0.994165
# ## Epoch[24], Train Loss: 0.042874   &   Train Accuracy: 99.123333
# ## Epoch[24], Test Loss: 0.059839   &   Test Accuracy: 98.760000
# Epoch[25]:
# Iteration[200]: Train Loss: 0.039879   Train Accuracy: 0.996977
# Iteration[400]: Train Loss: 0.041454   Train Accuracy: 0.993950
# ## Epoch[25], Train Loss: 0.041520   &   Train Accuracy: 99.143333
# ## Epoch[25], Test Loss: 0.059651   &   Test Accuracy: 98.630000
# Epoch[26]:
# Iteration[200]: Train Loss: 0.040601   Train Accuracy: 0.997252
# Iteration[400]: Train Loss: 0.040744   Train Accuracy: 0.994067
# ## Epoch[26], Train Loss: 0.040840   &   Train Accuracy: 99.151667
# ## Epoch[26], Test Loss: 0.058958   &   Test Accuracy: 98.740000
# Epoch[27]:
# Iteration[200]: Train Loss: 0.039679   Train Accuracy: 0.997173
# Iteration[400]: Train Loss: 0.040548   Train Accuracy: 0.994655
# ## Epoch[27], Train Loss: 0.040479   &   Train Accuracy: 99.205000
# ## Epoch[27], Test Loss: 0.060948   &   Test Accuracy: 98.650000
# Epoch[28]:
# Iteration[200]: Train Loss: 0.039505   Train Accuracy: 0.997213
# Iteration[400]: Train Loss: 0.040456   Train Accuracy: 0.994518
# ## Epoch[28], Train Loss: 0.040800   &   Train Accuracy: 99.193333
# ## Epoch[28], Test Loss: 0.058827   &   Test Accuracy: 98.670000
# Epoch[29]:
# Iteration[200]: Train Loss: 0.038481   Train Accuracy: 0.997566
# Iteration[400]: Train Loss: 0.039166   Train Accuracy: 0.994948
# ## Epoch[29], Train Loss: 0.039444   &   Train Accuracy: 99.220000
# ## Epoch[29], Test Loss: 0.060582   &   Test Accuracy: 98.750000
# Epoch[30]:
# Iteration[200]: Train Loss: 0.035492   Train Accuracy: 0.998390
# Iteration[400]: Train Loss: 0.039649   Train Accuracy: 0.994811
# ## Epoch[30], Train Loss: 0.039756   &   Train Accuracy: 99.210000
# ## Epoch[30], Test Loss: 0.059268   &   Test Accuracy: 98.720000
# Epoch[31]:
# Iteration[200]: Train Loss: 0.036520   Train Accuracy: 0.997644
# Iteration[400]: Train Loss: 0.039203   Train Accuracy: 0.994478
# ## Epoch[31], Train Loss: 0.039321   &   Train Accuracy: 99.186667
# ## Epoch[31], Test Loss: 0.059246   &   Test Accuracy: 98.720000
# Epoch[32]:
# Iteration[200]: Train Loss: 0.040270   Train Accuracy: 0.996742
# Iteration[400]: Train Loss: 0.039364   Train Accuracy: 0.994596
# ## Epoch[32], Train Loss: 0.038966   &   Train Accuracy: 99.210000
# ## Epoch[32], Test Loss: 0.059134   &   Test Accuracy: 98.680000
# Epoch[33]:
# Iteration[200]: Train Loss: 0.039639   Train Accuracy: 0.997291
# Iteration[400]: Train Loss: 0.039684   Train Accuracy: 0.994615
# ## Epoch[33], Train Loss: 0.038862   &   Train Accuracy: 99.213333
# ## Epoch[33], Test Loss: 0.058167   &   Test Accuracy: 98.750000
# Epoch[34]:
# Iteration[200]: Train Loss: 0.035859   Train Accuracy: 0.998430
# Iteration[400]: Train Loss: 0.038501   Train Accuracy: 0.995164
# ## Epoch[34], Train Loss: 0.038157   &   Train Accuracy: 99.270000
# ## Epoch[34], Test Loss: 0.058268   &   Test Accuracy: 98.670000
# Epoch[35]:
# Iteration[200]: Train Loss: 0.035401   Train Accuracy: 0.997566
# Iteration[400]: Train Loss: 0.037564   Train Accuracy: 0.994909
# ## Epoch[35], Train Loss: 0.037994   &   Train Accuracy: 99.233333
# ## Epoch[35], Test Loss: 0.057923   &   Test Accuracy: 98.710000
# Epoch[36]:
# Iteration[200]: Train Loss: 0.036759   Train Accuracy: 0.998116
# Iteration[400]: Train Loss: 0.037259   Train Accuracy: 0.995262
# ## Epoch[36], Train Loss: 0.037778   &   Train Accuracy: 99.250000
# ## Epoch[36], Test Loss: 0.061174   &   Test Accuracy: 98.690000
# Epoch[37]:
# Iteration[200]: Train Loss: 0.036413   Train Accuracy: 0.998194
# Iteration[400]: Train Loss: 0.037152   Train Accuracy: 0.995320
# ## Epoch[37], Train Loss: 0.037483   &   Train Accuracy: 99.265000
# ## Epoch[37], Test Loss: 0.056670   &   Test Accuracy: 98.760000
# Epoch[38]:
# Iteration[200]: Train Loss: 0.033796   Train Accuracy: 0.999215
# Iteration[400]: Train Loss: 0.036531   Train Accuracy: 0.995457
# ## Epoch[38], Train Loss: 0.037266   &   Train Accuracy: 99.263333
# ## Epoch[38], Test Loss: 0.059049   &   Test Accuracy: 98.740000
# Epoch[39]:
# Iteration[200]: Train Loss: 0.034495   Train Accuracy: 0.998901
# Iteration[400]: Train Loss: 0.036855   Train Accuracy: 0.995555
# ## Epoch[39], Train Loss: 0.037505   &   Train Accuracy: 99.286667
# ## Epoch[39], Test Loss: 0.057564   &   Test Accuracy: 98.710000
# Epoch[40]:
# Iteration[200]: Train Loss: 0.036445   Train Accuracy: 0.997880
# Iteration[400]: Train Loss: 0.036480   Train Accuracy: 0.995066
# ## Epoch[40], Train Loss: 0.036093   &   Train Accuracy: 99.260000
# ## Epoch[40], Test Loss: 0.058665   &   Test Accuracy: 98.710000
# Epoch[41]:
# Iteration[200]: Train Loss: 0.037834   Train Accuracy: 0.998312
# Iteration[400]: Train Loss: 0.036861   Train Accuracy: 0.995536
# ## Epoch[41], Train Loss: 0.036685   &   Train Accuracy: 99.286667
# ## Epoch[41], Test Loss: 0.057717   &   Test Accuracy: 98.820000
# Epoch[42]:
# Iteration[200]: Train Loss: 0.035097   Train Accuracy: 0.998626
# Iteration[400]: Train Loss: 0.035161   Train Accuracy: 0.995497
# ## Epoch[42], Train Loss: 0.036302   &   Train Accuracy: 99.281667
# ## Epoch[42], Test Loss: 0.057610   &   Test Accuracy: 98.700000
# Epoch[43]:
# Iteration[200]: Train Loss: 0.035335   Train Accuracy: 0.998273
# Iteration[400]: Train Loss: 0.036788   Train Accuracy: 0.995144
# ## Epoch[43], Train Loss: 0.036321   &   Train Accuracy: 99.275000
# ## Epoch[43], Test Loss: 0.056741   &   Test Accuracy: 98.780000
# Epoch[44]:
# Iteration[200]: Train Loss: 0.035467   Train Accuracy: 0.998665
# Iteration[400]: Train Loss: 0.035613   Train Accuracy: 0.995575
# ## Epoch[44], Train Loss: 0.035729   &   Train Accuracy: 99.291667
# ## Epoch[44], Test Loss: 0.061321   &   Test Accuracy: 98.620000
# Epoch[45]:
# Iteration[200]: Train Loss: 0.034965   Train Accuracy: 0.998430
# Iteration[400]: Train Loss: 0.036284   Train Accuracy: 0.995457
# ## Epoch[45], Train Loss: 0.035835   &   Train Accuracy: 99.298333
# ## Epoch[45], Test Loss: 0.058268   &   Test Accuracy: 98.770000
# Epoch[46]:
# Iteration[200]: Train Loss: 0.037749   Train Accuracy: 0.997566
# Iteration[400]: Train Loss: 0.036769   Train Accuracy: 0.995281
# ## Epoch[46], Train Loss: 0.036227   &   Train Accuracy: 99.300000
# ## Epoch[46], Test Loss: 0.058491   &   Test Accuracy: 98.790000
# Epoch[47]:
# Iteration[200]: Train Loss: 0.035526   Train Accuracy: 0.998076
# Iteration[400]: Train Loss: 0.034620   Train Accuracy: 0.995790
# ## Epoch[47], Train Loss: 0.035312   &   Train Accuracy: 99.315000
# ## Epoch[47], Test Loss: 0.057774   &   Test Accuracy: 98.730000
# Epoch[48]:
# Iteration[200]: Train Loss: 0.035431   Train Accuracy: 0.997998
# Iteration[400]: Train Loss: 0.034402   Train Accuracy: 0.995810
# ## Epoch[48], Train Loss: 0.034915   &   Train Accuracy: 99.321667
# ## Epoch[48], Test Loss: 0.057435   &   Test Accuracy: 98.790000
# Epoch[49]:
# Iteration[200]: Train Loss: 0.033513   Train Accuracy: 0.999058
# Iteration[400]: Train Loss: 0.035468   Train Accuracy: 0.995829
# ## Epoch[49], Train Loss: 0.035038   &   Train Accuracy: 99.338333
# ## Epoch[49], Test Loss: 0.058274   &   Test Accuracy: 98.780000
# Epoch[0]:
# Iteration[200]: Train Loss: 0.743308   Train Accuracy: 0.787571
# Iteration[400]: Train Loss: 0.489543   Train Accuracy: 0.862097
# ## Epoch[0], Train Loss: 0.446363   &   Train Accuracy: 87.260000
# ## Epoch[0], Test Loss: 0.162376   &   Test Accuracy: 95.710000
# Epoch[1]:
# Iteration[200]: Train Loss: 0.171875   Train Accuracy: 0.957993
# Iteration[400]: Train Loss: 0.157948   Train Accuracy: 0.959743
# ## Epoch[1], Train Loss: 0.154223   &   Train Accuracy: 95.860000
# ## Epoch[1], Test Loss: 0.113276   &   Test Accuracy: 97.130000
# Epoch[2]:
# Iteration[200]: Train Loss: 0.122344   Train Accuracy: 0.973226
# Iteration[400]: Train Loss: 0.118198   Train Accuracy: 0.971315
# ## Epoch[2], Train Loss: 0.116239   &   Train Accuracy: 96.943333
# ## Epoch[2], Test Loss: 0.090493   &   Test Accuracy: 97.780000
# Epoch[3]:
# Iteration[200]: Train Loss: 0.096389   Train Accuracy: 0.980724
# Iteration[400]: Train Loss: 0.096024   Train Accuracy: 0.978109
# ## Epoch[3], Train Loss: 0.094758   &   Train Accuracy: 97.603333
# ## Epoch[3], Test Loss: 0.078313   &   Test Accuracy: 98.080000
# Epoch[4]:
# Iteration[200]: Train Loss: 0.086340   Train Accuracy: 0.983158
# Iteration[400]: Train Loss: 0.082207   Train Accuracy: 0.981693
# ## Epoch[4], Train Loss: 0.082071   &   Train Accuracy: 97.926667
# ## Epoch[4], Test Loss: 0.071735   &   Test Accuracy: 98.270000
# Epoch[5]:
# Iteration[200]: Train Loss: 0.075233   Train Accuracy: 0.985631
# Iteration[400]: Train Loss: 0.074470   Train Accuracy: 0.983788
# ## Epoch[5], Train Loss: 0.073552   &   Train Accuracy: 98.186667
# ## Epoch[5], Test Loss: 0.069481   &   Test Accuracy: 98.210000
# Epoch[6]:
# Iteration[200]: Train Loss: 0.067929   Train Accuracy: 0.989322
# Iteration[400]: Train Loss: 0.067554   Train Accuracy: 0.986646
# ## Epoch[6], Train Loss: 0.068048   &   Train Accuracy: 98.390000
# ## Epoch[6], Test Loss: 0.064905   &   Test Accuracy: 98.450000
# Epoch[7]:
# Iteration[200]: Train Loss: 0.064918   Train Accuracy: 0.990068
# Iteration[400]: Train Loss: 0.062677   Train Accuracy: 0.987547
# ## Epoch[7], Train Loss: 0.063134   &   Train Accuracy: 98.501667
# ## Epoch[7], Test Loss: 0.064523   &   Test Accuracy: 98.480000
# Epoch[8]:
# Iteration[200]: Train Loss: 0.064312   Train Accuracy: 0.990068
# Iteration[400]: Train Loss: 0.060801   Train Accuracy: 0.988134
# ## Epoch[8], Train Loss: 0.060454   &   Train Accuracy: 98.565000
# ## Epoch[8], Test Loss: 0.059636   &   Test Accuracy: 98.520000
# Epoch[9]:
# Iteration[200]: Train Loss: 0.060300   Train Accuracy: 0.990931
# Iteration[400]: Train Loss: 0.057684   Train Accuracy: 0.989094
# ## Epoch[9], Train Loss: 0.057067   &   Train Accuracy: 98.696667
# ## Epoch[9], Test Loss: 0.059967   &   Test Accuracy: 98.590000
# Epoch[10]:
# Iteration[200]: Train Loss: 0.054651   Train Accuracy: 0.993247
# Iteration[400]: Train Loss: 0.055626   Train Accuracy: 0.990249
# ## Epoch[10], Train Loss: 0.054800   &   Train Accuracy: 98.768333
# ## Epoch[10], Test Loss: 0.058548   &   Test Accuracy: 98.590000
# Epoch[11]:
# Iteration[200]: Train Loss: 0.051709   Train Accuracy: 0.992816
# Iteration[400]: Train Loss: 0.052536   Train Accuracy: 0.990660
# ## Epoch[11], Train Loss: 0.053034   &   Train Accuracy: 98.786667
# ## Epoch[11], Test Loss: 0.056470   &   Test Accuracy: 98.660000
# Epoch[12]:
# Iteration[200]: Train Loss: 0.050363   Train Accuracy: 0.993993
# Iteration[400]: Train Loss: 0.051211   Train Accuracy: 0.991228
# ## Epoch[12], Train Loss: 0.051600   &   Train Accuracy: 98.838333
# ## Epoch[12], Test Loss: 0.056895   &   Test Accuracy: 98.640000
# Epoch[13]:
# Iteration[200]: Train Loss: 0.049882   Train Accuracy: 0.993954
# Iteration[400]: Train Loss: 0.050372   Train Accuracy: 0.991365
# ## Epoch[13], Train Loss: 0.050170   &   Train Accuracy: 98.883333
# ## Epoch[13], Test Loss: 0.055499   &   Test Accuracy: 98.690000
# Epoch[14]:
# Iteration[200]: Train Loss: 0.049049   Train Accuracy: 0.994818
# Iteration[400]: Train Loss: 0.047730   Train Accuracy: 0.992050
# ## Epoch[14], Train Loss: 0.047898   &   Train Accuracy: 98.958333
# ## Epoch[14], Test Loss: 0.057164   &   Test Accuracy: 98.620000
# Epoch[15]:
# Iteration[200]: Train Loss: 0.047596   Train Accuracy: 0.994190
# Iteration[400]: Train Loss: 0.047648   Train Accuracy: 0.991698
# ## Epoch[15], Train Loss: 0.047022   &   Train Accuracy: 98.935000
# ## Epoch[15], Test Loss: 0.054765   &   Test Accuracy: 98.700000
# Epoch[16]:
# Iteration[200]: Train Loss: 0.046492   Train Accuracy: 0.995564
# Iteration[400]: Train Loss: 0.046725   Train Accuracy: 0.992853
# ## Epoch[16], Train Loss: 0.046462   &   Train Accuracy: 99.038333
# ## Epoch[16], Test Loss: 0.054570   &   Test Accuracy: 98.650000
# Epoch[17]:
# Iteration[200]: Train Loss: 0.045390   Train Accuracy: 0.995210
# Iteration[400]: Train Loss: 0.043932   Train Accuracy: 0.992990
# ## Epoch[17], Train Loss: 0.045291   &   Train Accuracy: 99.033333
# ## Epoch[17], Test Loss: 0.054203   &   Test Accuracy: 98.790000
# Epoch[18]:
# Iteration[200]: Train Loss: 0.043186   Train Accuracy: 0.995917
# Iteration[400]: Train Loss: 0.044947   Train Accuracy: 0.992853
# ## Epoch[18], Train Loss: 0.044557   &   Train Accuracy: 99.040000
# ## Epoch[18], Test Loss: 0.054968   &   Test Accuracy: 98.770000
# Epoch[19]:
# Iteration[200]: Train Loss: 0.044087   Train Accuracy: 0.995289
# Iteration[400]: Train Loss: 0.044102   Train Accuracy: 0.993323
# ## Epoch[19], Train Loss: 0.043938   &   Train Accuracy: 99.083333
# ## Epoch[19], Test Loss: 0.054394   &   Test Accuracy: 98.770000
# Epoch[20]:
# Iteration[200]: Train Loss: 0.042558   Train Accuracy: 0.996035
# Iteration[400]: Train Loss: 0.042859   Train Accuracy: 0.993441
# ## Epoch[20], Train Loss: 0.042635   &   Train Accuracy: 99.105000
# ## Epoch[20], Test Loss: 0.054802   &   Test Accuracy: 98.750000
# Epoch[21]:
# Iteration[200]: Train Loss: 0.040821   Train Accuracy: 0.996742
# Iteration[400]: Train Loss: 0.041056   Train Accuracy: 0.994302
# ## Epoch[21], Train Loss: 0.041071   &   Train Accuracy: 99.171667
# ## Epoch[21], Test Loss: 0.053236   &   Test Accuracy: 98.780000
# Epoch[22]:
# Iteration[200]: Train Loss: 0.041742   Train Accuracy: 0.996427
# Iteration[400]: Train Loss: 0.042301   Train Accuracy: 0.993715
# ## Epoch[22], Train Loss: 0.041430   &   Train Accuracy: 99.135000
# ## Epoch[22], Test Loss: 0.053493   &   Test Accuracy: 98.720000
# Epoch[23]:
# Iteration[200]: Train Loss: 0.039587   Train Accuracy: 0.997095
# Iteration[400]: Train Loss: 0.040394   Train Accuracy: 0.994498
# ## Epoch[23], Train Loss: 0.040776   &   Train Accuracy: 99.171667
# ## Epoch[23], Test Loss: 0.054422   &   Test Accuracy: 98.760000
# Epoch[24]:
# Iteration[200]: Train Loss: 0.041845   Train Accuracy: 0.996467
# Iteration[400]: Train Loss: 0.039876   Train Accuracy: 0.994576
# ## Epoch[24], Train Loss: 0.039603   &   Train Accuracy: 99.205000
# ## Epoch[24], Test Loss: 0.053868   &   Test Accuracy: 98.810000
# Epoch[25]:
# Iteration[200]: Train Loss: 0.040569   Train Accuracy: 0.996506
# Iteration[400]: Train Loss: 0.040152   Train Accuracy: 0.994185
# ## Epoch[25], Train Loss: 0.039861   &   Train Accuracy: 99.166667
# ## Epoch[25], Test Loss: 0.051961   &   Test Accuracy: 98.860000
# Epoch[26]:
# Iteration[200]: Train Loss: 0.038728   Train Accuracy: 0.998076
# Iteration[400]: Train Loss: 0.038970   Train Accuracy: 0.995027
# ## Epoch[26], Train Loss: 0.039041   &   Train Accuracy: 99.235000
# ## Epoch[26], Test Loss: 0.052650   &   Test Accuracy: 98.830000
# Epoch[27]:
# Iteration[200]: Train Loss: 0.037239   Train Accuracy: 0.997605
# Iteration[400]: Train Loss: 0.038507   Train Accuracy: 0.994909
# ## Epoch[27], Train Loss: 0.039122   &   Train Accuracy: 99.218333
# ## Epoch[27], Test Loss: 0.051666   &   Test Accuracy: 98.830000
# Epoch[28]:
# Iteration[200]: Train Loss: 0.036398   Train Accuracy: 0.998351
# Iteration[400]: Train Loss: 0.037387   Train Accuracy: 0.995418
# ## Epoch[28], Train Loss: 0.038493   &   Train Accuracy: 99.273333
# ## Epoch[28], Test Loss: 0.051915   &   Test Accuracy: 98.860000
# Epoch[29]:
# Iteration[200]: Train Loss: 0.036677   Train Accuracy: 0.998116
# Iteration[400]: Train Loss: 0.037117   Train Accuracy: 0.995379
# ## Epoch[29], Train Loss: 0.037198   &   Train Accuracy: 99.270000
# ## Epoch[29], Test Loss: 0.051871   &   Test Accuracy: 98.880000
# Epoch[30]:
# Iteration[200]: Train Loss: 0.038529   Train Accuracy: 0.997919
# Iteration[400]: Train Loss: 0.038124   Train Accuracy: 0.995144
# ## Epoch[30], Train Loss: 0.037701   &   Train Accuracy: 99.266667
# ## Epoch[30], Test Loss: 0.052022   &   Test Accuracy: 98.860000
# Epoch[31]:
# Iteration[200]: Train Loss: 0.036706   Train Accuracy: 0.997527
# Iteration[400]: Train Loss: 0.037032   Train Accuracy: 0.995301
# ## Epoch[31], Train Loss: 0.036756   &   Train Accuracy: 99.283333
# ## Epoch[31], Test Loss: 0.052264   &   Test Accuracy: 98.920000
# Epoch[32]:
# Iteration[200]: Train Loss: 0.036608   Train Accuracy: 0.998076
# Iteration[400]: Train Loss: 0.037284   Train Accuracy: 0.995438
# ## Epoch[32], Train Loss: 0.037215   &   Train Accuracy: 99.286667
# ## Epoch[32], Test Loss: 0.052895   &   Test Accuracy: 98.870000
# Epoch[33]:
# Iteration[200]: Train Loss: 0.035752   Train Accuracy: 0.997762
# Iteration[400]: Train Loss: 0.036362   Train Accuracy: 0.995320
# ## Epoch[33], Train Loss: 0.036819   &   Train Accuracy: 99.281667
# ## Epoch[33], Test Loss: 0.053116   &   Test Accuracy: 98.790000
# Epoch[34]:
# Iteration[200]: Train Loss: 0.034716   Train Accuracy: 0.998744
# Iteration[400]: Train Loss: 0.036002   Train Accuracy: 0.995732
# ## Epoch[34], Train Loss: 0.036241   &   Train Accuracy: 99.310000
# ## Epoch[34], Test Loss: 0.052699   &   Test Accuracy: 98.810000
# Epoch[35]:
# Iteration[200]: Train Loss: 0.033882   Train Accuracy: 0.998901
# Iteration[400]: Train Loss: 0.035113   Train Accuracy: 0.996162
# ## Epoch[35], Train Loss: 0.036317   &   Train Accuracy: 99.336667
# ## Epoch[35], Test Loss: 0.051390   &   Test Accuracy: 98.870000
# Epoch[36]:
# Iteration[200]: Train Loss: 0.034336   Train Accuracy: 0.998547
# Iteration[400]: Train Loss: 0.035999   Train Accuracy: 0.995653
# ## Epoch[36], Train Loss: 0.035538   &   Train Accuracy: 99.310000
# ## Epoch[36], Test Loss: 0.052421   &   Test Accuracy: 98.900000
# Epoch[37]:
# Iteration[200]: Train Loss: 0.035526   Train Accuracy: 0.998626
# Iteration[400]: Train Loss: 0.036185   Train Accuracy: 0.995771
# ## Epoch[37], Train Loss: 0.036191   &   Train Accuracy: 99.320000
# ## Epoch[37], Test Loss: 0.052341   &   Test Accuracy: 98.830000
# Epoch[38]:
# Iteration[200]: Train Loss: 0.034028   Train Accuracy: 0.998940
# Iteration[400]: Train Loss: 0.035996   Train Accuracy: 0.995771
# ## Epoch[38], Train Loss: 0.035473   &   Train Accuracy: 99.331667
# ## Epoch[38], Test Loss: 0.051360   &   Test Accuracy: 98.860000
# Epoch[39]:
# Iteration[200]: Train Loss: 0.033554   Train Accuracy: 0.998665
# Iteration[400]: Train Loss: 0.035360   Train Accuracy: 0.995888
# ## Epoch[39], Train Loss: 0.035256   &   Train Accuracy: 99.330000
# ## Epoch[39], Test Loss: 0.051863   &   Test Accuracy: 98.890000
# Epoch[40]:
# Iteration[200]: Train Loss: 0.034578   Train Accuracy: 0.999176
# Iteration[400]: Train Loss: 0.034736   Train Accuracy: 0.996260
# ## Epoch[40], Train Loss: 0.034679   &   Train Accuracy: 99.366667
# ## Epoch[40], Test Loss: 0.050078   &   Test Accuracy: 98.840000
# Epoch[41]:
# Iteration[200]: Train Loss: 0.034593   Train Accuracy: 0.999333
# Iteration[400]: Train Loss: 0.034485   Train Accuracy: 0.996299
# ## Epoch[41], Train Loss: 0.034725   &   Train Accuracy: 99.366667
# ## Epoch[41], Test Loss: 0.053452   &   Test Accuracy: 98.900000
# Epoch[42]:
# Iteration[200]: Train Loss: 0.032411   Train Accuracy: 0.999176
# Iteration[400]: Train Loss: 0.035227   Train Accuracy: 0.996025
# ## Epoch[42], Train Loss: 0.034771   &   Train Accuracy: 99.356667
# ## Epoch[42], Test Loss: 0.050731   &   Test Accuracy: 98.850000
# Epoch[43]:
# Iteration[200]: Train Loss: 0.035379   Train Accuracy: 0.999058
# Iteration[400]: Train Loss: 0.034028   Train Accuracy: 0.996456
# ## Epoch[43], Train Loss: 0.034601   &   Train Accuracy: 99.380000
# ## Epoch[43], Test Loss: 0.050804   &   Test Accuracy: 98.840000
# Epoch[44]:
# Iteration[200]: Train Loss: 0.032014   Train Accuracy: 0.999254
# Iteration[400]: Train Loss: 0.034302   Train Accuracy: 0.996456
# ## Epoch[44], Train Loss: 0.034196   &   Train Accuracy: 99.381667
# ## Epoch[44], Test Loss: 0.051712   &   Test Accuracy: 98.950000
# Epoch[45]:
# Iteration[200]: Train Loss: 0.033804   Train Accuracy: 0.998547
# Iteration[400]: Train Loss: 0.034649   Train Accuracy: 0.995849
# ## Epoch[45], Train Loss: 0.034066   &   Train Accuracy: 99.358333
# ## Epoch[45], Test Loss: 0.051351   &   Test Accuracy: 98.850000
# Epoch[46]:
# Iteration[200]: Train Loss: 0.034449   Train Accuracy: 0.998822
# Iteration[400]: Train Loss: 0.033251   Train Accuracy: 0.996632
# ## Epoch[46], Train Loss: 0.033936   &   Train Accuracy: 99.396667
# ## Epoch[46], Test Loss: 0.050052   &   Test Accuracy: 98.920000
# Epoch[47]:
# Iteration[200]: Train Loss: 0.034239   Train Accuracy: 0.999136
# Iteration[400]: Train Loss: 0.033155   Train Accuracy: 0.996730
# ## Epoch[47], Train Loss: 0.033580   &   Train Accuracy: 99.398333
# ## Epoch[47], Test Loss: 0.053468   &   Test Accuracy: 98.910000
# Epoch[48]:
# Iteration[200]: Train Loss: 0.033442   Train Accuracy: 0.998979
# Iteration[400]: Train Loss: 0.033677   Train Accuracy: 0.996280
# ## Epoch[48], Train Loss: 0.033578   &   Train Accuracy: 99.373333
# ## Epoch[48], Test Loss: 0.051419   &   Test Accuracy: 98.910000
# Epoch[49]:
# Iteration[200]: Train Loss: 0.032995   Train Accuracy: 0.999176
# Iteration[400]: Train Loss: 0.032694   Train Accuracy: 0.996515
# ## Epoch[49], Train Loss: 0.033108   &   Train Accuracy: 99.391667
# ## Epoch[49], Test Loss: 0.050987   &   Test Accuracy: 98.920000
# Epoch[0]:
# Iteration[200]: Train Loss: 1.010933   Train Accuracy: 0.680394
# Iteration[400]: Train Loss: 0.597726   Train Accuracy: 0.817180
# ## Epoch[0], Train Loss: 0.531883   &   Train Accuracy: 83.631667
# ## Epoch[0], Test Loss: 0.132451   &   Test Accuracy: 96.570000
# Epoch[1]:
# Iteration[200]: Train Loss: 0.130350   Train Accuracy: 0.972440
# Iteration[400]: Train Loss: 0.123268   Train Accuracy: 0.971589
# ## Epoch[1], Train Loss: 0.118698   &   Train Accuracy: 97.028333
# ## Epoch[1], Test Loss: 0.095393   &   Test Accuracy: 97.610000
# Epoch[2]:
# Iteration[200]: Train Loss: 0.100282   Train Accuracy: 0.979899
# Iteration[400]: Train Loss: 0.094979   Train Accuracy: 0.978540
# ## Epoch[2], Train Loss: 0.093837   &   Train Accuracy: 97.640000
# ## Epoch[2], Test Loss: 0.079004   &   Test Accuracy: 98.020000
# Epoch[3]:
# Iteration[200]: Train Loss: 0.081796   Train Accuracy: 0.985435
# Iteration[400]: Train Loss: 0.080462   Train Accuracy: 0.983044
# ## Epoch[3], Train Loss: 0.079936   &   Train Accuracy: 98.048333
# ## Epoch[3], Test Loss: 0.069945   &   Test Accuracy: 98.260000
# Epoch[4]:
# Iteration[200]: Train Loss: 0.071891   Train Accuracy: 0.988301
# Iteration[400]: Train Loss: 0.072387   Train Accuracy: 0.985139
# ## Epoch[4], Train Loss: 0.071739   &   Train Accuracy: 98.290000
# ## Epoch[4], Test Loss: 0.064548   &   Test Accuracy: 98.420000
# Epoch[5]:
# Iteration[200]: Train Loss: 0.066506   Train Accuracy: 0.988851
# Iteration[400]: Train Loss: 0.065067   Train Accuracy: 0.986901
# ## Epoch[5], Train Loss: 0.065194   &   Train Accuracy: 98.458333
# ## Epoch[5], Test Loss: 0.061548   &   Test Accuracy: 98.440000
# Epoch[6]:
# Iteration[200]: Train Loss: 0.060251   Train Accuracy: 0.990970
# Iteration[400]: Train Loss: 0.060825   Train Accuracy: 0.988487
# ## Epoch[6], Train Loss: 0.060738   &   Train Accuracy: 98.608333
# ## Epoch[6], Test Loss: 0.058357   &   Test Accuracy: 98.540000
# Epoch[7]:
# Iteration[200]: Train Loss: 0.056797   Train Accuracy: 0.992541
# Iteration[400]: Train Loss: 0.056683   Train Accuracy: 0.989446
# ## Epoch[7], Train Loss: 0.057327   &   Train Accuracy: 98.681667
# ## Epoch[7], Test Loss: 0.056482   &   Test Accuracy: 98.610000
# Epoch[8]:
# Iteration[200]: Train Loss: 0.053285   Train Accuracy: 0.993287
# Iteration[400]: Train Loss: 0.053805   Train Accuracy: 0.990425
# ## Epoch[8], Train Loss: 0.054296   &   Train Accuracy: 98.781667
# ## Epoch[8], Test Loss: 0.056006   &   Test Accuracy: 98.660000
# Epoch[9]:
# Iteration[200]: Train Loss: 0.051537   Train Accuracy: 0.993836
# Iteration[400]: Train Loss: 0.051833   Train Accuracy: 0.991013
# ## Epoch[9], Train Loss: 0.051724   &   Train Accuracy: 98.866667
# ## Epoch[9], Test Loss: 0.054441   &   Test Accuracy: 98.740000
# Epoch[10]:
# Iteration[200]: Train Loss: 0.049908   Train Accuracy: 0.994661
# Iteration[400]: Train Loss: 0.049922   Train Accuracy: 0.991953
# ## Epoch[10], Train Loss: 0.050049   &   Train Accuracy: 98.950000
# ## Epoch[10], Test Loss: 0.053722   &   Test Accuracy: 98.780000
# Epoch[11]:
# Iteration[200]: Train Loss: 0.048709   Train Accuracy: 0.994425
# Iteration[400]: Train Loss: 0.048738   Train Accuracy: 0.992246
# ## Epoch[11], Train Loss: 0.048501   &   Train Accuracy: 98.958333
# ## Epoch[11], Test Loss: 0.052878   &   Test Accuracy: 98.860000
# Epoch[12]:
# Iteration[200]: Train Loss: 0.043544   Train Accuracy: 0.995799
# Iteration[400]: Train Loss: 0.046981   Train Accuracy: 0.992481
# ## Epoch[12], Train Loss: 0.046720   &   Train Accuracy: 98.993333
# ## Epoch[12], Test Loss: 0.051426   &   Test Accuracy: 98.860000
# Epoch[13]:
# Iteration[200]: Train Loss: 0.044317   Train Accuracy: 0.996506
# Iteration[400]: Train Loss: 0.045311   Train Accuracy: 0.993127
# ## Epoch[13], Train Loss: 0.045235   &   Train Accuracy: 99.058333
# ## Epoch[13], Test Loss: 0.052187   &   Test Accuracy: 98.930000
# Epoch[14]:
# Iteration[200]: Train Loss: 0.043861   Train Accuracy: 0.995682
# Iteration[400]: Train Loss: 0.044400   Train Accuracy: 0.993539
# ## Epoch[14], Train Loss: 0.043867   &   Train Accuracy: 99.111667
# ## Epoch[14], Test Loss: 0.053658   &   Test Accuracy: 98.760000
# Epoch[15]:
# Iteration[200]: Train Loss: 0.042346   Train Accuracy: 0.996899
# Iteration[400]: Train Loss: 0.043422   Train Accuracy: 0.993656
# ## Epoch[15], Train Loss: 0.043081   &   Train Accuracy: 99.115000
# ## Epoch[15], Test Loss: 0.051000   &   Test Accuracy: 98.880000
# Epoch[16]:
# Iteration[200]: Train Loss: 0.042557   Train Accuracy: 0.997252
# Iteration[400]: Train Loss: 0.042190   Train Accuracy: 0.994243
# ## Epoch[16], Train Loss: 0.041546   &   Train Accuracy: 99.203333
# ## Epoch[16], Test Loss: 0.052206   &   Test Accuracy: 98.830000
# Epoch[17]:
# Iteration[200]: Train Loss: 0.040978   Train Accuracy: 0.996977
# Iteration[400]: Train Loss: 0.041574   Train Accuracy: 0.994263
# ## Epoch[17], Train Loss: 0.041343   &   Train Accuracy: 99.178333
# ## Epoch[17], Test Loss: 0.050895   &   Test Accuracy: 98.970000
# Epoch[18]:
# Iteration[200]: Train Loss: 0.041968   Train Accuracy: 0.996663
# Iteration[400]: Train Loss: 0.040401   Train Accuracy: 0.994831
# ## Epoch[18], Train Loss: 0.039941   &   Train Accuracy: 99.238333
# ## Epoch[18], Test Loss: 0.054183   &   Test Accuracy: 98.900000
# Epoch[19]:
# Iteration[200]: Train Loss: 0.036917   Train Accuracy: 0.997762
# Iteration[400]: Train Loss: 0.039142   Train Accuracy: 0.994870
# ## Epoch[19], Train Loss: 0.039207   &   Train Accuracy: 99.256667
# ## Epoch[19], Test Loss: 0.051590   &   Test Accuracy: 98.910000
# Epoch[20]:
# Iteration[200]: Train Loss: 0.039077   Train Accuracy: 0.998430
# Iteration[400]: Train Loss: 0.038751   Train Accuracy: 0.995732
# ## Epoch[20], Train Loss: 0.038367   &   Train Accuracy: 99.315000
# ## Epoch[20], Test Loss: 0.052538   &   Test Accuracy: 98.890000
# Epoch[21]:
# Iteration[200]: Train Loss: 0.038566   Train Accuracy: 0.998469
# Iteration[400]: Train Loss: 0.038423   Train Accuracy: 0.995673
# ## Epoch[21], Train Loss: 0.037638   &   Train Accuracy: 99.335000
# ## Epoch[21], Test Loss: 0.053065   &   Test Accuracy: 98.910000
# Epoch[22]:
# Iteration[200]: Train Loss: 0.034052   Train Accuracy: 0.999176
# Iteration[400]: Train Loss: 0.036864   Train Accuracy: 0.995869
# ## Epoch[22], Train Loss: 0.036787   &   Train Accuracy: 99.343333
# ## Epoch[22], Test Loss: 0.052779   &   Test Accuracy: 98.920000
# Epoch[23]:
# Iteration[200]: Train Loss: 0.035003   Train Accuracy: 0.998861
# Iteration[400]: Train Loss: 0.036069   Train Accuracy: 0.995869
# ## Epoch[23], Train Loss: 0.036487   &   Train Accuracy: 99.336667
# ## Epoch[23], Test Loss: 0.051043   &   Test Accuracy: 98.960000
# Epoch[24]:
# Iteration[200]: Train Loss: 0.030258   Train Accuracy: 1.000196
# Iteration[400]: Train Loss: 0.035496   Train Accuracy: 0.996417
# ...
# ## Epoch[41], Train Loss: 0.029659   &   Train Accuracy: 99.496667
# ## Epoch[41], Test Loss: 0.052735   &   Test Accuracy: 98.930000
# Epoch[42]:
# Iteration[200]: Train Loss: 0.029333   Train Accuracy: 1.000707
# Iteration[400]: Train Loss: 0.029880   Train Accuracy: 0.997885
# ## Epoch[42], Train Loss: 0.030341   &   Train Accuracy: 99.510000
# ## Epoch[42], Test Loss: 0.051550   &   Test Accuracy: 98.980000
# Epoch[43]:
# Iteration[200]: Train Loss: 0.026989   Train Accuracy: 1.000942
# Iteration[400]: Train Loss: 0.029364   Train Accuracy: 0.997552
# ## Epoch[43], Train Loss: 0.029305   &   Train Accuracy: 99.515000
# ## Epoch[43], Test Loss: 0.052102   &   Test Accuracy: 99.000000
# Epoch[44]:
# Iteration[200]: Train Loss: 0.028712   Train Accuracy: 1.000471
# Iteration[400]: Train Loss: 0.028971   Train Accuracy: 0.998022
# ## Epoch[44], Train Loss: 0.029102   &   Train Accuracy: 99.538333
# ## Epoch[44], Test Loss: 0.053969   &   Test Accuracy: 98.970000
# Epoch[45]:
# Iteration[200]: Train Loss: 0.027442   Train Accuracy: 1.000942
# Iteration[400]: Train Loss: 0.028464   Train Accuracy: 0.997983
# ## Epoch[45], Train Loss: 0.028692   &   Train Accuracy: 99.545000
# ## Epoch[45], Test Loss: 0.056100   &   Test Accuracy: 98.910000
# Epoch[46]:
# Iteration[200]: Train Loss: 0.026627   Train Accuracy: 1.000864
# Iteration[400]: Train Loss: 0.027808   Train Accuracy: 0.997964
# ## Epoch[46], Train Loss: 0.028633   &   Train Accuracy: 99.531667
# ## Epoch[46], Test Loss: 0.053490   &   Test Accuracy: 98.930000
# Epoch[47]:
# Iteration[200]: Train Loss: 0.028041   Train Accuracy: 1.000707
# Iteration[400]: Train Loss: 0.028394   Train Accuracy: 0.998199
# ## Epoch[47], Train Loss: 0.028257   &   Train Accuracy: 99.565000
# ## Epoch[47], Test Loss: 0.057408   &   Test Accuracy: 98.910000
# Epoch[48]:
# Iteration[200]: Train Loss: 0.028011   Train Accuracy: 1.000510
# Iteration[400]: Train Loss: 0.027786   Train Accuracy: 0.998140
# ## Epoch[48], Train Loss: 0.028721   &   Train Accuracy: 99.535000
# ## Epoch[48], Test Loss: 0.054885   &   Test Accuracy: 98.880000
# Epoch[49]:
# Iteration[200]: Train Loss: 0.026704   Train Accuracy: 1.001217
# Iteration[400]: Train Loss: 0.027857   Train Accuracy: 0.998218
# ## Epoch[49], Train Loss: 0.028345   &   Train Accuracy: 99.565000
# ## Epoch[49], Test Loss: 0.055408   &   Test Accuracy: 98.940000
# Epoch[0]:
# Iteration[200]: Train Loss: 1.024467   Train Accuracy: 0.676822
# Iteration[400]: Train Loss: 0.616846   Train Accuracy: 0.810816
# ## Epoch[0], Train Loss: 0.549504   &   Train Accuracy: 83.025000
# ## Epoch[0], Test Loss: 0.145585   &   Test Accuracy: 96.040000
# Epoch[1]:
# Iteration[200]: Train Loss: 0.149343   Train Accuracy: 0.965099
# Iteration[400]: Train Loss: 0.140562   Train Accuracy: 0.965304
# ## Epoch[1], Train Loss: 0.136544   &   Train Accuracy: 96.415000
# ## Epoch[1], Test Loss: 0.111154   &   Test Accuracy: 97.110000
# Epoch[2]:
# Iteration[200]: Train Loss: 0.112119   Train Accuracy: 0.975660
# Iteration[400]: Train Loss: 0.111009   Train Accuracy: 0.973997
# ## Epoch[2], Train Loss: 0.110700   &   Train Accuracy: 97.155000
# ## Epoch[2], Test Loss: 0.097204   &   Test Accuracy: 97.420000
# Epoch[3]:
# Iteration[200]: Train Loss: 0.099278   Train Accuracy: 0.979075
# Iteration[400]: Train Loss: 0.097294   Train Accuracy: 0.977228
# ## Epoch[3], Train Loss: 0.096465   &   Train Accuracy: 97.495000
# ## Epoch[3], Test Loss: 0.088475   &   Test Accuracy: 97.680000
# Epoch[4]:
# Iteration[200]: Train Loss: 0.091169   Train Accuracy: 0.981980
# Iteration[400]: Train Loss: 0.090288   Train Accuracy: 0.979382
# ## Epoch[4], Train Loss: 0.088248   &   Train Accuracy: 97.730000
# ## Epoch[4], Test Loss: 0.083173   &   Test Accuracy: 97.750000
# Epoch[5]:
# Iteration[200]: Train Loss: 0.082594   Train Accuracy: 0.984022
# Iteration[400]: Train Loss: 0.082156   Train Accuracy: 0.982104
# ## Epoch[5], Train Loss: 0.080783   &   Train Accuracy: 97.990000
# ## Epoch[5], Test Loss: 0.079236   &   Test Accuracy: 97.870000
# Epoch[6]:
# Iteration[200]: Train Loss: 0.081236   Train Accuracy: 0.984493
# Iteration[400]: Train Loss: 0.076991   Train Accuracy: 0.983396
# ## Epoch[6], Train Loss: 0.075939   &   Train Accuracy: 98.148333
# ## Epoch[6], Test Loss: 0.077029   &   Test Accuracy: 97.970000
# Epoch[7]:
# Iteration[200]: Train Loss: 0.069714   Train Accuracy: 0.988301
# Iteration[400]: Train Loss: 0.072469   Train Accuracy: 0.985099
# ## Epoch[7], Train Loss: 0.072270   &   Train Accuracy: 98.251667
# ## Epoch[7], Test Loss: 0.072590   &   Test Accuracy: 98.160000
# Epoch[8]:
# Iteration[200]: Train Loss: 0.070214   Train Accuracy: 0.988144
# Iteration[400]: Train Loss: 0.069179   Train Accuracy: 0.985569
# ## Epoch[8], Train Loss: 0.068216   &   Train Accuracy: 98.345000
# ## Epoch[8], Test Loss: 0.073149   &   Test Accuracy: 98.070000
# Epoch[9]:
# Iteration[200]: Train Loss: 0.069064   Train Accuracy: 0.988105
# Iteration[400]: Train Loss: 0.066520   Train Accuracy: 0.986353
# ## Epoch[9], Train Loss: 0.065608   &   Train Accuracy: 98.420000
# ## Epoch[9], Test Loss: 0.068539   &   Test Accuracy: 98.210000
# Epoch[10]:
# Iteration[200]: Train Loss: 0.059241   Train Accuracy: 0.990656
# Iteration[400]: Train Loss: 0.061235   Train Accuracy: 0.987860
# ## Epoch[10], Train Loss: 0.062356   &   Train Accuracy: 98.515000
# ## Epoch[10], Test Loss: 0.068178   &   Test Accuracy: 98.340000
# Epoch[11]:
# Iteration[200]: Train Loss: 0.062281   Train Accuracy: 0.990068
# Iteration[400]: Train Loss: 0.061279   Train Accuracy: 0.987919
# ## Epoch[11], Train Loss: 0.060926   &   Train Accuracy: 98.545000
# ## Epoch[11], Test Loss: 0.068869   &   Test Accuracy: 98.260000
# Epoch[12]:
# Iteration[200]: Train Loss: 0.058870   Train Accuracy: 0.991088
# Iteration[400]: Train Loss: 0.059547   Train Accuracy: 0.988781
# ## Epoch[12], Train Loss: 0.058637   &   Train Accuracy: 98.631667
# ## Epoch[12], Test Loss: 0.067130   &   Test Accuracy: 98.350000
# Epoch[13]:
# Iteration[200]: Train Loss: 0.058328   Train Accuracy: 0.991795
# Iteration[400]: Train Loss: 0.056734   Train Accuracy: 0.989466
# ## Epoch[13], Train Loss: 0.056973   &   Train Accuracy: 98.678333
# ## Epoch[13], Test Loss: 0.067038   &   Test Accuracy: 98.350000
# Epoch[14]:
# Iteration[200]: Train Loss: 0.054042   Train Accuracy: 0.992659
# Iteration[400]: Train Loss: 0.054640   Train Accuracy: 0.990034
# ## Epoch[14], Train Loss: 0.055459   &   Train Accuracy: 98.725000
# ## Epoch[14], Test Loss: 0.064490   &   Test Accuracy: 98.450000
# Epoch[15]:
# Iteration[200]: Train Loss: 0.051969   Train Accuracy: 0.992580
# Iteration[400]: Train Loss: 0.054037   Train Accuracy: 0.990151
# ## Epoch[15], Train Loss: 0.054431   &   Train Accuracy: 98.753333
# ## Epoch[15], Test Loss: 0.065028   &   Test Accuracy: 98.560000
# Epoch[16]:
# Iteration[200]: Train Loss: 0.054531   Train Accuracy: 0.992030
# Iteration[400]: Train Loss: 0.053474   Train Accuracy: 0.990171
# ## Epoch[16], Train Loss: 0.053311   &   Train Accuracy: 98.763333
# ## Epoch[16], Test Loss: 0.063651   &   Test Accuracy: 98.520000
# Epoch[17]:
# Iteration[200]: Train Loss: 0.051454   Train Accuracy: 0.992659
# Iteration[400]: Train Loss: 0.050955   Train Accuracy: 0.990523
# ## Epoch[17], Train Loss: 0.051426   &   Train Accuracy: 98.790000
# ## Epoch[17], Test Loss: 0.066586   &   Test Accuracy: 98.390000
# Epoch[18]:
# Iteration[200]: Train Loss: 0.050498   Train Accuracy: 0.994229
# Iteration[400]: Train Loss: 0.050722   Train Accuracy: 0.991287
# ## Epoch[18], Train Loss: 0.050671   &   Train Accuracy: 98.871667
# ## Epoch[18], Test Loss: 0.065913   &   Test Accuracy: 98.480000
# Epoch[19]:
# Iteration[200]: Train Loss: 0.048857   Train Accuracy: 0.994425
# Iteration[400]: Train Loss: 0.049213   Train Accuracy: 0.991267
# ## Epoch[19], Train Loss: 0.049271   &   Train Accuracy: 98.890000
# ## Epoch[19], Test Loss: 0.064783   &   Test Accuracy: 98.530000
# Epoch[20]:
# Iteration[200]: Train Loss: 0.049133   Train Accuracy: 0.994896
# Iteration[400]: Train Loss: 0.048870   Train Accuracy: 0.991796
# ## Epoch[20], Train Loss: 0.048683   &   Train Accuracy: 98.920000
# ## Epoch[20], Test Loss: 0.064854   &   Test Accuracy: 98.540000
# Epoch[21]:
# Iteration[200]: Train Loss: 0.049409   Train Accuracy: 0.993836
# Iteration[400]: Train Loss: 0.048189   Train Accuracy: 0.991835
# ## Epoch[21], Train Loss: 0.047842   &   Train Accuracy: 98.950000
# ## Epoch[21], Test Loss: 0.065196   &   Test Accuracy: 98.510000
# Epoch[22]:
# Iteration[200]: Train Loss: 0.047440   Train Accuracy: 0.994150
# Iteration[400]: Train Loss: 0.047659   Train Accuracy: 0.991933
# ## Epoch[22], Train Loss: 0.046785   &   Train Accuracy: 98.951667
# ## Epoch[22], Test Loss: 0.064527   &   Test Accuracy: 98.530000
# Epoch[23]:
# Iteration[200]: Train Loss: 0.047069   Train Accuracy: 0.994582
# Iteration[400]: Train Loss: 0.046513   Train Accuracy: 0.992305
# ## Epoch[23], Train Loss: 0.046532   &   Train Accuracy: 98.985000
# ## Epoch[23], Test Loss: 0.065571   &   Test Accuracy: 98.520000
# Epoch[24]:
# Iteration[200]: Train Loss: 0.043815   Train Accuracy: 0.995799
# Iteration[400]: Train Loss: 0.046228   Train Accuracy: 0.992520
# ## Epoch[24], Train Loss: 0.045569   &   Train Accuracy: 99.003333
# ## Epoch[24], Test Loss: 0.064953   &   Test Accuracy: 98.540000
# Epoch[25]:
# Iteration[200]: Train Loss: 0.046080   Train Accuracy: 0.994386
# Iteration[400]: Train Loss: 0.045574   Train Accuracy: 0.992344
# ## Epoch[25], Train Loss: 0.045564   &   Train Accuracy: 99.001667
# ## Epoch[25], Test Loss: 0.063393   &   Test Accuracy: 98.590000
# Epoch[26]:
# Iteration[200]: Train Loss: 0.044104   Train Accuracy: 0.995328
# Iteration[400]: Train Loss: 0.044159   Train Accuracy: 0.992971
# ## Epoch[26], Train Loss: 0.044502   &   Train Accuracy: 99.026667
# ## Epoch[26], Test Loss: 0.065371   &   Test Accuracy: 98.470000
# Epoch[27]:
# Iteration[200]: Train Loss: 0.046221   Train Accuracy: 0.995171
# Iteration[400]: Train Loss: 0.044165   Train Accuracy: 0.993029
# ## Epoch[27], Train Loss: 0.044194   &   Train Accuracy: 99.043333
# ## Epoch[27], Test Loss: 0.065085   &   Test Accuracy: 98.550000
# Epoch[28]:
# Iteration[200]: Train Loss: 0.040473   Train Accuracy: 0.997291
# Iteration[400]: Train Loss: 0.042875   Train Accuracy: 0.993597
# ## Epoch[28], Train Loss: 0.043222   &   Train Accuracy: 99.111667
# ## Epoch[28], Test Loss: 0.066226   &   Test Accuracy: 98.530000
# Epoch[29]:
# Iteration[200]: Train Loss: 0.040937   Train Accuracy: 0.995878
# Iteration[400]: Train Loss: 0.042822   Train Accuracy: 0.993421
# ## Epoch[29], Train Loss: 0.043232   &   Train Accuracy: 99.068333
# ## Epoch[29], Test Loss: 0.065097   &   Test Accuracy: 98.560000
# Epoch[30]:
# Iteration[200]: Train Loss: 0.040299   Train Accuracy: 0.997252
# Iteration[400]: Train Loss: 0.043003   Train Accuracy: 0.993734
# ## Epoch[30], Train Loss: 0.042567   &   Train Accuracy: 99.120000
# ## Epoch[30], Test Loss: 0.064865   &   Test Accuracy: 98.490000
# Epoch[31]:
# Iteration[200]: Train Loss: 0.042339   Train Accuracy: 0.996388
# Iteration[400]: Train Loss: 0.041824   Train Accuracy: 0.993813
# ## Epoch[31], Train Loss: 0.042401   &   Train Accuracy: 99.116667
# ## Epoch[31], Test Loss: 0.063270   &   Test Accuracy: 98.590000
# Epoch[32]:
# Iteration[200]: Train Loss: 0.038914   Train Accuracy: 0.997684
# Iteration[400]: Train Loss: 0.041872   Train Accuracy: 0.993734
# ## Epoch[32], Train Loss: 0.041860   &   Train Accuracy: 99.125000
# ## Epoch[32], Test Loss: 0.063211   &   Test Accuracy: 98.650000
# Epoch[33]:
# Iteration[200]: Train Loss: 0.039455   Train Accuracy: 0.997095
# Iteration[400]: Train Loss: 0.040990   Train Accuracy: 0.993989
# ## Epoch[33], Train Loss: 0.041791   &   Train Accuracy: 99.115000
# ## Epoch[33], Test Loss: 0.066778   &   Test Accuracy: 98.610000
# Epoch[34]:
# Iteration[200]: Train Loss: 0.039347   Train Accuracy: 0.996663
# Iteration[400]: Train Loss: 0.045805   Train Accuracy: 0.993343
# ## Epoch[34], Train Loss: 0.045038   &   Train Accuracy: 99.101667
# ## Epoch[34], Test Loss: 0.062475   &   Test Accuracy: 98.590000
# Epoch[35]:
# Iteration[200]: Train Loss: 0.038361   Train Accuracy: 0.996859
# Iteration[400]: Train Loss: 0.040077   Train Accuracy: 0.993950
# ## Epoch[35], Train Loss: 0.039877   &   Train Accuracy: 99.150000
# ## Epoch[35], Test Loss: 0.064692   &   Test Accuracy: 98.600000
# Epoch[36]:
# Iteration[200]: Train Loss: 0.039238   Train Accuracy: 0.996977
# Iteration[400]: Train Loss: 0.039863   Train Accuracy: 0.993930
# ## Epoch[36], Train Loss: 0.040512   &   Train Accuracy: 99.133333
# ## Epoch[36], Test Loss: 0.064173   &   Test Accuracy: 98.560000
# Epoch[37]:
# Iteration[200]: Train Loss: 0.038546   Train Accuracy: 0.996702
# Iteration[400]: Train Loss: 0.039836   Train Accuracy: 0.994048
# ## Epoch[37], Train Loss: 0.039930   &   Train Accuracy: 99.161667
# ## Epoch[37], Test Loss: 0.064369   &   Test Accuracy: 98.600000
# Epoch[38]:
# Iteration[200]: Train Loss: 0.039460   Train Accuracy: 0.996899
# Iteration[400]: Train Loss: 0.039644   Train Accuracy: 0.994341
# ## Epoch[38], Train Loss: 0.039794   &   Train Accuracy: 99.180000
# ## Epoch[38], Test Loss: 0.064844   &   Test Accuracy: 98.630000
# Epoch[39]:
# Iteration[200]: Train Loss: 0.041684   Train Accuracy: 0.996310
# Iteration[400]: Train Loss: 0.038964   Train Accuracy: 0.994322
# ## Epoch[39], Train Loss: 0.039175   &   Train Accuracy: 99.183333
# ## Epoch[39], Test Loss: 0.063698   &   Test Accuracy: 98.660000
# Epoch[40]:
# Iteration[200]: Train Loss: 0.036920   Train Accuracy: 0.997605
# Iteration[400]: Train Loss: 0.038578   Train Accuracy: 0.994400
# ## Epoch[40], Train Loss: 0.039684   &   Train Accuracy: 99.175000
# ## Epoch[40], Test Loss: 0.064528   &   Test Accuracy: 98.590000
# Epoch[41]:
# Iteration[200]: Train Loss: 0.038170   Train Accuracy: 0.996859
# Iteration[400]: Train Loss: 0.038383   Train Accuracy: 0.994420
# ## Epoch[41], Train Loss: 0.038975   &   Train Accuracy: 99.181667
# ## Epoch[41], Test Loss: 0.063798   &   Test Accuracy: 98.650000
# Epoch[42]:
# Iteration[200]: Train Loss: 0.036472   Train Accuracy: 0.997684
# Iteration[400]: Train Loss: 0.038578   Train Accuracy: 0.995027
# ## Epoch[42], Train Loss: 0.038899   &   Train Accuracy: 99.238333
# ## Epoch[42], Test Loss: 0.064433   &   Test Accuracy: 98.580000
# Epoch[43]:
# Iteration[200]: Train Loss: 0.037563   Train Accuracy: 0.997252
# Iteration[400]: Train Loss: 0.039123   Train Accuracy: 0.994380
# ## Epoch[43], Train Loss: 0.038840   &   Train Accuracy: 99.190000
# ## Epoch[43], Test Loss: 0.065059   &   Test Accuracy: 98.570000
# Epoch[44]:
# Iteration[200]: Train Loss: 0.039111   Train Accuracy: 0.997016
# Iteration[400]: Train Loss: 0.039186   Train Accuracy: 0.994596
# ## Epoch[44], Train Loss: 0.039011   &   Train Accuracy: 99.223333
# ## Epoch[44], Test Loss: 0.064071   &   Test Accuracy: 98.660000
# Epoch[45]:
# Iteration[200]: Train Loss: 0.038428   Train Accuracy: 0.998312
# Iteration[400]: Train Loss: 0.038304   Train Accuracy: 0.994890
# ## Epoch[45], Train Loss: 0.038625   &   Train Accuracy: 99.221667
# ## Epoch[45], Test Loss: 0.063207   &   Test Accuracy: 98.530000
# Epoch[46]:
# Iteration[200]: Train Loss: 0.038677   Train Accuracy: 0.996859
# Iteration[400]: Train Loss: 0.037829   Train Accuracy: 0.994850
# ## Epoch[46], Train Loss: 0.038839   &   Train Accuracy: 99.220000
# ## Epoch[46], Test Loss: 0.063730   &   Test Accuracy: 98.610000
# Epoch[47]:
# Iteration[200]: Train Loss: 0.037077   Train Accuracy: 0.997605
# Iteration[400]: Train Loss: 0.037802   Train Accuracy: 0.994792
# ## Epoch[47], Train Loss: 0.038055   &   Train Accuracy: 99.226667
# ## Epoch[47], Test Loss: 0.062612   &   Test Accuracy: 98.620000
# Epoch[48]:
# Iteration[200]: Train Loss: 0.037401   Train Accuracy: 0.997802
# Iteration[400]: Train Loss: 0.038535   Train Accuracy: 0.994831
# ## Epoch[48], Train Loss: 0.038568   &   Train Accuracy: 99.241667
# ## Epoch[48], Test Loss: 0.064651   &   Test Accuracy: 98.540000
# Epoch[49]:
# Iteration[200]: Train Loss: 0.034208   Train Accuracy: 0.998390
# Iteration[400]: Train Loss: 0.036966   Train Accuracy: 0.995222
# ## Epoch[49], Train Loss: 0.037641   &   Train Accuracy: 99.261667
# ## Epoch[49], Test Loss: 0.062474   &   Test Accuracy: 98.610000

# %% [markdown]
# ## Ensemble

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
BATCH_SIZE = 1024
TEST_BATCH_SIZE = 128

TRAIN_SIZE = len(trainloader.dataset)
TEST_SIZE = len(testloader.dataset)
print(TRAIN_SIZE)
print(TEST_SIZE)
NUM_BATCHES = len(trainloader)
NUM_TEST_BATCHES = len(testloader)

CLASSES = 10
TRAIN_EPOCHS = 50
TEST_SAMPLES = 2
# Out:
# 60000
# 10000

# %%
for num_ensembles in range (total_ensembles):
  for epoch in range(TRAIN_EPOCHS):
    model_save_name = 'MNIST_model{}_epoch{}'.format(num_ensembles + 1,epoch)    
    path = "/content/gdrive/My Drive/CS7643ModelsTesting/MNISTModels/{}".format(model_save_name) 
    checkpoint = torch.load(path)
    net_ensemble[num_ensembles].load_state_dict(checkpoint)

# for i in range(len(net_ensemble)):
#   model_save_name = 'BBB_model{}_epoch{}'.format(i+1,)    
#   path = "/content/gdrive/My Drive/testing_bbb/SavedModels/{}".format(model_save_name) 
#   checkpoint = torch.load(path)
#   net_ensemble[i].load_state_dict(checkpoint)

# %%
def prediction_BBB(data,net):
    net.eval()
    with torch.no_grad():
        data= data.to(DEVICE)
        outputs = torch.zeros(TEST_SAMPLES+1, TEST_BATCH_SIZE, CLASSES).to(DEVICE)
        for i in range(TEST_SAMPLES):
            # print("1: ", outputs[i].shape)
            temp = torch.exp(net(data))
            # print("2: ", temp.shape)
            outputs[i] = temp    #11*5*10    11 predictions of 5 images with 10 classes
        outputs[TEST_SAMPLES] = torch.exp(net(data))
        output = outputs.mean(0)      #5*10       mean of 11 predictions for each of the 5 image with 10 classes     
    return output

def prediction_deep_BBB(image, net_ensemble):
    probs = 0
    for net in net_ensemble:
        probs += prediction_BBB(image,net)
    mean = probs/len(net_ensemble)
    return mean

# %%
test_loss_BBB, accuracy_BBB = 0, 0
accuracy_BBB2 = 0
accuracy_BBB3 = 0
accuracy_BBB4 = 0
accuracy_BBB5 = 0

test_loss_deep_BBB, accuracy_deep_BBB = 0, 0
criterion = nn.NLLLoss()
count = 0
for images, labels in testloader:
  count += 1
  if count < len(testloader):
    images=images.to(DEVICE)
    labels=labels.to(DEVICE)

    for net in net_ensemble:
      net.train()       

    log_ps_BBB = torch.log(prediction_BBB(images,net_ensemble[0]))
    test_loss_BBB += criterion(log_ps_BBB, labels)
    ps = torch.exp(log_ps_BBB)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    accuracy_BBB += torch.mean(equals.type(torch.FloatTensor))

    log_ps_BBB = torch.log(prediction_BBB(images,net_ensemble[1]))
    test_loss_BBB += criterion(log_ps_BBB, labels)
    ps = torch.exp(log_ps_BBB)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    accuracy_BBB2 += torch.mean(equals.type(torch.FloatTensor))

    log_ps_BBB = torch.log(prediction_BBB(images,net_ensemble[2]))
    test_loss_BBB += criterion(log_ps_BBB, labels)
    ps = torch.exp(log_ps_BBB)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    accuracy_BBB3 += torch.mean(equals.type(torch.FloatTensor))

    log_ps_BBB = torch.log(prediction_BBB(images,net_ensemble[3]))
    test_loss_BBB += criterion(log_ps_BBB, labels)
    ps = torch.exp(log_ps_BBB)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    accuracy_BBB4 += torch.mean(equals.type(torch.FloatTensor))

    log_ps_BBB = torch.log(prediction_BBB(images,net_ensemble[4]))
    test_loss_BBB += criterion(log_ps_BBB, labels)
    ps = torch.exp(log_ps_BBB)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    accuracy_BBB5 += torch.mean(equals.type(torch.FloatTensor))


    log_ps_deepBBB = torch.log(prediction_deep_BBB(images,net_ensemble))
    test_loss_deep_BBB += criterion(log_ps_deepBBB, labels)
    ps = torch.exp(log_ps_deepBBB)
    top_p, top_class = ps.topk(1, dim=1)
    equals = top_class == labels.view(*top_class.shape)
    accuracy_deep_BBB += torch.mean(equals.type(torch.FloatTensor))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
bbb_acc = accuracy_BBB/len(testloader)
deep_bbb_acc = accuracy_deep_BBB/len(testloader)

print(bbb_acc)
print(accuracy_BBB2/len(testloader))
print(accuracy_BBB3/len(testloader))
print(accuracy_BBB4/len(testloader))
print(accuracy_BBB5/len(testloader))
print()
print()
print(deep_bbb_acc)
# Out:
# tensor(0.9731)
# tensor(0.9741)
# tensor(0.9764)
# tensor(0.9767)
# tensor(0.9731)
#
#
# tensor(0.9798)
